# %% [markdown]
# <a href="https://colab.research.google.com/github/hongsua05/baekjoon/blob/main/EEGNet_%EA%B8%B0%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motor Imagery Task Classification

# %% [markdown]
# #Extracting Data

# %% [markdown]
# ##Downloading BCI Competition IV 2a Dataset

# %%
# !wget https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# Out:
# --2026-05-18 08:25:35--  https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# Resolving www.bbci.de (www.bbci.de)... 141.23.71.83
# Connecting to www.bbci.de (www.bbci.de)|141.23.71.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 439968864 (420M) [application/zip]
# Saving to: ‘BCICIV_2a_gdf.zip’
#
# BCICIV_2a_gdf.zip   100%[===================>] 419.59M  20.5MB/s    in 21s
#
# 2026-05-18 08:25:57 (20.1 MB/s) - ‘BCICIV_2a_gdf.zip’ saved [439968864/439968864]

# %%
# !mkdir -p /content/cleaned_data/

# %%
# %%capture
# !unzip /content/BCICIV_2a_gdf.zip -d raw_data

# %%
# !find /content/raw_data -name "*.gdf" | wc -l
# Out:
# 18

# %% [markdown]
# #Installing Packages

# %%
# %%capture
# !pip install mne

# %%
# %%capture
# !pip install torch-summary

# %% [markdown]
# #Libraries Used

# %%
import os
import mne
import math
import copy
import gdown
import random
import scipy.io
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Building Dataset

# %%
# !mkdir -p /content/cleaned_data/first_session
# !mkdir -p /content/cleaned_data/second_session

# %% [markdown]
# ##First Session

# %%
raw_data_folder = '/content/raw_data/'
cleaned_data_folder = '/content/cleaned_data/first_session/'
files = os.listdir(raw_data_folder)

# Selecting files with suffix 'T.gdf'
filtered_files = [file for file in files if file.endswith('T.gdf')]

raw_list = []

# Iterating through filtered files
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Reading raw data
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
    # Droping EOG channels
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # High Pass Filtering 4-40 Hz
    raw.filter(l_freq=4, h_freq=40, method='iir')

    # Notch filter for Removal of Line Voltage
    raw.notch_filter(freqs=50)

    # Saving the modified raw data to a file with .fif suffix
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)
    # Appending data to the list
    raw_list.append(raw)

final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'First_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting GDF parameters from /content/raw_data/A09T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A09T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A09T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A09T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A05T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A05T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A05T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A05T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A07T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A07T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A07T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A07T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A04T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 600914  =      0.000 ...  2403.656 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A04T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A04T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A04T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A06T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A06T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A06T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A06T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A03T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A03T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A03T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A03T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A02T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A02T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A02T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A02T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A01T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A01T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A01T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A01T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A08T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A08T.fif
# /tmp/ipykernel_1137/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A08T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A08T.fif
# [done]
# Writing /content/cleaned_data/first_session/First_Session_Subjects.fif
# /tmp/ipykernel_1137/468050219.py:33: RuntimeWarning: This filename (/content/cleaned_data/first_session/First_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/First_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/first_session/First_Session_Subjects.fif')]

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '769': 7 Cue onset **Left** (class 1) : 0
# '770': 8 Cue onset **Right** (class 2) : 1
# '771': 9 Cue onset **Foot** (class 3) : 2
# '772': 10 Cue onset **Tongue** (class 4): 3

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('769'), np.str_('770'), np.str_('771'), np.str_('772')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('769'): 7,
#  np.str_('770'): 8,
#  np.str_('771'): 9,
#  np.str_('772'): 10}

# %% [markdown]
# **Time choice:**
# [0.s, 4s] Post Cue on set:  [2s, 6s]

# %%
epochs = mne.Epochs(final_raw, events[0], event_id=[7, 8], tmin=0, tmax=4, reject=None, baseline=None, preload=True)
first_session_data = epochs.get_data(copy=True)
first_session_labels = epochs.events[:,-1]
# 7: Left hand → 0
# 8: Right hand → 1
first_session_labels = first_session_labels - 7
first_session_labels = first_session_labels.astype(int)
# Out:
# Not setting metadata
# 1296 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1296 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
print("First_session_dataset shape:",first_session_data.shape)
# Out:
# First_session_dataset shape: (1296, 22, 1001)

# %% [markdown]
# ##Second Session

# %% [markdown]
# ###Extracting Labels for datas with "E.gdf" prefix

# %%
# Replace this with your actual shareable link
shareable_link = 'https://drive.google.com/file/d/11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo/view?usp=drive_link'

# Extract file ID from the shareable link
file_id = shareable_link.split('/d/')[1].split('/view')[0]

# Create the direct download link
download_url = f'https://drive.google.com/uc?id={file_id}&export=download'

# Specify the output file path
output_file = 'true_labels.zip'

# Download the file
gdown.download(download_url, output_file, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo&export=download
# To: /content/true_labels.zip
# 100%|██████████| 7.20k/7.20k [00:00<00:00, 20.6MB/s]
# 'true_labels.zip'

# %%
# %%capture
# !unzip /content/true_labels.zip -d second_session_labels

# %% [markdown]
# ###Extracting datas of second session

# %%
raw_data_folder = '/content/raw_data/'
cleaned_data_folder = '/content/cleaned_data/second_session/'
mat_folder = '/content/second_session_labels/'

# Selecting files with suffix 'E.mat'
mat_files = os.listdir(mat_folder)
filtered_math_labels = [file for file in mat_files if file.endswith('E.mat')]

# Selecting files with suffix 'E.gdf'
files = os.listdir(raw_data_folder)
filtered_files = [file for file in files if file.endswith('E.gdf')]

raw_list = []
second_session_labels = np.array([])
# Iterating through filtered files
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Reading raw data
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
    # Droping EOG channels
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # High Pass Filtering 4-40 Hz
    raw.filter(l_freq=4, h_freq=40, method='iir')

    # Saving the modified raw data to a file with .fif suffix
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)
    # Appending data to t he list
    raw_list.append(raw)

    # Mat files for the labels
    mat_file_name = file.replace('.gdf', '.mat')
    mat_file_path = os.path.join(mat_folder, mat_file_name)
    print(f"data:{file}, label:{mat_file_name}")

    if os.path.exists(mat_file_path):
        mat_data = scipy.io.loadmat(mat_file_path)
        class_labels = mat_data.get('classlabel', [])

        # Check if 'classlabel' key exists and is not empty
        if class_labels.size > 0:
             # Convert to a NumPy array and flatten
            class_labels_array = np.array(class_labels, dtype=int).flatten()
            # Concatenate with the existing test_labels array
            second_session_labels = np.concatenate((second_session_labels, class_labels_array))
        else:
            print(f"Warning: 'classlabel' not found or empty in {mat_file_name}.")
    else:
        print(f"Warning: {mat_file_name} not found.")

final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'Second_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting GDF parameters from /content/raw_data/A06E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 666372  =      0.000 ...  2665.488 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A06E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A06E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A06E.fif
# [done]
# data:A06E.gdf, label:A06E.mat
# Extracting GDF parameters from /content/raw_data/A08E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 687791  =      0.000 ...  2751.164 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A08E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A08E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A08E.fif
# [done]
# data:A08E.gdf, label:A08E.mat
# Extracting GDF parameters from /content/raw_data/A01E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686999  =      0.000 ...  2747.996 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A01E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A01E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A01E.fif
# [done]
# data:A01E.gdf, label:A01E.mat
# Extracting GDF parameters from /content/raw_data/A09E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 675097  =      0.000 ...  2700.388 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A09E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A09E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A09E.fif
# [done]
# data:A09E.gdf, label:A09E.mat
# Extracting GDF parameters from /content/raw_data/A05E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 679862  =      0.000 ...  2719.448 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A05E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A05E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A05E.fif
# [done]
# data:A05E.gdf, label:A05E.mat
# Extracting GDF parameters from /content/raw_data/A02E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 662665  =      0.000 ...  2650.660 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A02E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A02E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A02E.fif
# [done]
# data:A02E.gdf, label:A02E.mat
# Extracting GDF parameters from /content/raw_data/A04E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 660046  =      0.000 ...  2640.184 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A04E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A04E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A04E.fif
# [done]
# data:A04E.gdf, label:A04E.mat
# Extracting GDF parameters from /content/raw_data/A03E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 648774  =      0.000 ...  2595.096 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A03E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A03E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A03E.fif
# [done]
# data:A03E.gdf, label:A03E.mat
# Extracting GDF parameters from /content/raw_data/A07E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 673134  =      0.000 ...  2692.536 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A07E.fif
# /tmp/ipykernel_1137/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A07E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A07E.fif
# [done]
# data:A07E.gdf, label:A07E.mat
# Writing /content/cleaned_data/second_session/Second_Session_Subjects.fif
# /tmp/ipykernel_1137/2108108794.py:55: RuntimeWarning: This filename (/content/cleaned_data/second_session/Second_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/Second_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/second_session/Second_Session_Subjects.fif')]

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '783': 7 Cue unknown

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('783')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('783'): 7}

# %%
epochs = mne.Epochs(final_raw, events[0], event_id=7, tmin=0, tmax=4, reject=None, baseline=None, preload=None)
second_session_data = epochs.get_data(copy=True)
# Second session label은 true label 파일에서 가져온 값: 1,2,3,4
# 1 = left hand, 2 = right hand만 남김
mask = (second_session_labels == 1) | (second_session_labels == 2)

second_session_data = second_session_data[mask]
second_session_labels = second_session_labels[mask]

# 1: left hand → 0
# 2: right hand → 1
second_session_labels = second_session_labels - 1
second_session_labels = second_session_labels.astype(int)
# Out:
# Not setting metadata
# 2592 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2592 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
print("Second Session Dataset shape:",second_session_data.shape)
# Out:
# Second Session Dataset shape: (1296, 22, 1001)

# %% [markdown]
# ###Structuring Data

# %%
# Choosing Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loss Function
criterion = nn.CrossEntropyLoss()

# Labels are already normalized:
# first_session_labels: 0 = Left, 1 = Right
# second_session_labels: 0 = Left, 1 = Right
y_train = first_session_labels
y_test = second_session_labels

# Normalizing Input features: z-score(mean=0, std=1)
X_train = (first_session_data - np.mean(first_session_data)) / np.std(first_session_data)
X_test = (second_session_data - np.mean(second_session_data)) / np.std(second_session_data)

# Converting to Tensor
X_train = torch.Tensor(X_train).unsqueeze(1).to(device)
X_test = torch.Tensor(X_test).unsqueeze(1).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test = torch.LongTensor(y_test).to(device)

# Creating Tensor Dataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# Printing the sizes
print("Size of X_train:", X_train.size())
print("Size of X_test:", X_test.size())
print("Size of y_train:", y_train.size())
print("Size of y_test:", y_test.size())

print("Train labels:", torch.unique(y_train, return_counts=True))
print("Test labels:", torch.unique(y_test, return_counts=True))
# Out:
# Size of X_train: torch.Size([1296, 1, 22, 1001])
# Size of X_test: torch.Size([1296, 1, 22, 1001])
# Size of y_train: torch.Size([1296])
# Size of y_test: torch.Size([1296])
# Train labels: (tensor([0, 1], device='cuda:0'), tensor([648, 648], device='cuda:0'))
# Test labels: (tensor([0, 1], device='cuda:0'), tensor([648, 648], device='cuda:0'))

# %% [markdown]
# ddaining Class

# %%
class TrainModel():
    def __init__(self,):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def train_model(self, model, train_dataset, learning_rate=0.001, batch_size=64, epochs=500):
        model = model.to(self.device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        highest_train_accuracy = 0.0

        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            correct = 0
            total = 0
            for inputs, labels in train_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            epoch_loss = running_loss / len(train_loader.dataset)
            epoch_accuracy = correct / total
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy
            print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {(epoch_accuracy*100):.2f}%")

        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)
        print("Highest Train Accuracy:", highest_train_accuracy)

        # Saving model
        torch.save(model.state_dict(), 'eegnet_model.pth')
        return model

# %% [markdown]
# #Evaluating Model

# %%
class EvalModel():
    def __init__(self, model):
        self.model = model.to(device)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    def test_model(self, test_dataset):
        self.model.eval()
        correct = 0
        total = 0
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = (correct / total) * 100
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")
        return accuracy

    def plot_confusion_matrix(self, test_dataset, classes):
        self.model.eval()
        y_pred = []
        y_true = []
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                y_pred.append(predicted.item())
                y_true.append(labels.item())

        cf_matrix = confusion_matrix(y_true, y_pred)
        cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]

        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        plt.figure(figsize=(10, 7))
        sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='.2f')
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.savefig('confusion_matrix_model.png')
        plt.show()

# %% [markdown]
# #EEGNet Model

# %%
class EEGNetModel(nn.Module): # EEGNET-8,2
    def __init__(self, chans=22, classes=4, time_points=1001, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, dropout_rate=0.5, max_norm1=1, max_norm2=0.25):
        super(EEGNetModel, self).__init__()
        # Calculating FC input features
        linear_size = (time_points//(pk1*pk2))*f2

        # Temporal Filters
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )
        # Spatial Filters
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False), # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16),  groups=f2, bias=False, padding='same'), # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False), # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(linear_size, classes)

        # Apply max_norm constraint to the depthwise layer in block2
        self._apply_max_norm(self.block2[0], max_norm1)

        # Apply max_norm constraint to the linear layer
        self._apply_max_norm(self.fc, max_norm2)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ##Model Summery

# %%
input_size = (1, 22, 1001)
eegnet_model = EEGNetModel().to(device)
summary(eegnet_model, input_size)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:548: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv2d(
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 4]                   900
# ==========================================================================================
# Total params: 3,812
# Trainable params: 3,812
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.06
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 4]                   900
# ==========================================================================================
# Total params: 3,812
# Trainable params: 3,812
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.06
# ==========================================================================================

# %% [markdown]
# ##Training Model

# %%
eegnet_model = EEGNetModel(chans=22, classes=2, time_points=1001).to(device)

# Training Hyperparameters
EPOCHS = 500
BATCH_SIZE = 64
LEARNING_RATE = 0.001
trainer = TrainModel()
trained_eegnet_model = trainer.train_model(eegnet_model, train_dataset, learning_rate=LEARNING_RATE,
                                   batch_size=BATCH_SIZE, epochs=EPOCHS)
torch.save(trained_eegnet_model.state_dict(), 'eegnet_model.pth')
# Out:
# Epoch 1/500, Loss: 0.6922, Accuracy: 50.69%
# Epoch 2/500, Loss: 0.6888, Accuracy: 53.32%
# Epoch 3/500, Loss: 0.6831, Accuracy: 55.71%
# Epoch 4/500, Loss: 0.6714, Accuracy: 58.80%
# Epoch 5/500, Loss: 0.6535, Accuracy: 59.34%
# Epoch 6/500, Loss: 0.6322, Accuracy: 62.81%
# Epoch 7/500, Loss: 0.6040, Accuracy: 63.89%
# Epoch 8/500, Loss: 0.5832, Accuracy: 65.59%
# Epoch 9/500, Loss: 0.5762, Accuracy: 65.97%
# Epoch 10/500, Loss: 0.5543, Accuracy: 69.14%
# Epoch 11/500, Loss: 0.5611, Accuracy: 68.52%
# Epoch 12/500, Loss: 0.5367, Accuracy: 70.52%
# Epoch 13/500, Loss: 0.5373, Accuracy: 69.83%
# Epoch 14/500, Loss: 0.5105, Accuracy: 70.52%
# Epoch 15/500, Loss: 0.5247, Accuracy: 70.76%
# Epoch 16/500, Loss: 0.5198, Accuracy: 70.37%
# Epoch 17/500, Loss: 0.5113, Accuracy: 70.52%
# Epoch 18/500, Loss: 0.5150, Accuracy: 73.69%
# Epoch 19/500, Loss: 0.5026, Accuracy: 72.22%
# Epoch 20/500, Loss: 0.4886, Accuracy: 73.92%
# Epoch 21/500, Loss: 0.5060, Accuracy: 72.61%
# Epoch 22/500, Loss: 0.4974, Accuracy: 72.53%
# Epoch 23/500, Loss: 0.4974, Accuracy: 73.15%
# Epoch 24/500, Loss: 0.5036, Accuracy: 73.07%
# Epoch 25/500, Loss: 0.5003, Accuracy: 73.15%
# Epoch 26/500, Loss: 0.4954, Accuracy: 72.84%
# Epoch 27/500, Loss: 0.4944, Accuracy: 72.61%
# Epoch 28/500, Loss: 0.5013, Accuracy: 72.99%
# Epoch 29/500, Loss: 0.4890, Accuracy: 74.23%
# Epoch 30/500, Loss: 0.4725, Accuracy: 74.38%
# Epoch 31/500, Loss: 0.4924, Accuracy: 72.15%
# Epoch 32/500, Loss: 0.4780, Accuracy: 74.61%
# Epoch 33/500, Loss: 0.4785, Accuracy: 74.54%
# Epoch 34/500, Loss: 0.4828, Accuracy: 74.69%
# Epoch 35/500, Loss: 0.4872, Accuracy: 73.84%
# Epoch 36/500, Loss: 0.4896, Accuracy: 73.07%
# Epoch 37/500, Loss: 0.4657, Accuracy: 75.46%
# Epoch 38/500, Loss: 0.4884, Accuracy: 74.15%
# Epoch 39/500, Loss: 0.4684, Accuracy: 74.31%
# Epoch 40/500, Loss: 0.4735, Accuracy: 74.92%
# Epoch 41/500, Loss: 0.4517, Accuracy: 78.78%
# Epoch 42/500, Loss: 0.4596, Accuracy: 76.00%
# Epoch 43/500, Loss: 0.4726, Accuracy: 75.00%
# Epoch 44/500, Loss: 0.4780, Accuracy: 74.07%
# Epoch 45/500, Loss: 0.4652, Accuracy: 75.69%
# Epoch 46/500, Loss: 0.4712, Accuracy: 74.69%
# Epoch 47/500, Loss: 0.4580, Accuracy: 75.93%
# Epoch 48/500, Loss: 0.4592, Accuracy: 75.77%
# Epoch 49/500, Loss: 0.4498, Accuracy: 76.47%
# Epoch 50/500, Loss: 0.4520, Accuracy: 76.16%
# Epoch 51/500, Loss: 0.4618, Accuracy: 76.00%
# Epoch 52/500, Loss: 0.4734, Accuracy: 73.77%
# Epoch 53/500, Loss: 0.4653, Accuracy: 75.00%
# Epoch 54/500, Loss: 0.4512, Accuracy: 76.85%
# Epoch 55/500, Loss: 0.4394, Accuracy: 76.62%
# Epoch 56/500, Loss: 0.4484, Accuracy: 77.55%
# Epoch 57/500, Loss: 0.4672, Accuracy: 75.08%
# Epoch 58/500, Loss: 0.4557, Accuracy: 76.31%
# Epoch 59/500, Loss: 0.4272, Accuracy: 77.08%
# Epoch 60/500, Loss: 0.4495, Accuracy: 76.08%
# Epoch 61/500, Loss: 0.4275, Accuracy: 78.24%
# Epoch 62/500, Loss: 0.4375, Accuracy: 77.31%
# Epoch 63/500, Loss: 0.4445, Accuracy: 77.55%
# Epoch 64/500, Loss: 0.4359, Accuracy: 79.01%
# Epoch 65/500, Loss: 0.4447, Accuracy: 76.23%
# Epoch 66/500, Loss: 0.4255, Accuracy: 78.16%
# Epoch 67/500, Loss: 0.4455, Accuracy: 77.85%
# Epoch 68/500, Loss: 0.4449, Accuracy: 76.93%
# Epoch 69/500, Loss: 0.4494, Accuracy: 76.39%
# Epoch 70/500, Loss: 0.4217, Accuracy: 77.93%
# Epoch 71/500, Loss: 0.4354, Accuracy: 77.62%
# Epoch 72/500, Loss: 0.4331, Accuracy: 77.62%
# Epoch 73/500, Loss: 0.4423, Accuracy: 76.31%
# Epoch 74/500, Loss: 0.4405, Accuracy: 77.31%
# Epoch 75/500, Loss: 0.4307, Accuracy: 77.31%
# Epoch 76/500, Loss: 0.4332, Accuracy: 76.93%
# Epoch 77/500, Loss: 0.4333, Accuracy: 79.71%
# Epoch 78/500, Loss: 0.4312, Accuracy: 77.24%
# Epoch 79/500, Loss: 0.4303, Accuracy: 78.09%
# Epoch 80/500, Loss: 0.4340, Accuracy: 78.63%
# Epoch 81/500, Loss: 0.4095, Accuracy: 79.48%
# Epoch 82/500, Loss: 0.4179, Accuracy: 78.78%
# Epoch 83/500, Loss: 0.4298, Accuracy: 78.01%
# Epoch 84/500, Loss: 0.4240, Accuracy: 78.40%
# Epoch 85/500, Loss: 0.4376, Accuracy: 76.70%
# Epoch 86/500, Loss: 0.4246, Accuracy: 78.78%
# Epoch 87/500, Loss: 0.4107, Accuracy: 79.40%
# Epoch 88/500, Loss: 0.4186, Accuracy: 78.32%
# Epoch 89/500, Loss: 0.4201, Accuracy: 79.32%
# Epoch 90/500, Loss: 0.4186, Accuracy: 77.78%
# Epoch 91/500, Loss: 0.4227, Accuracy: 78.47%
# Epoch 92/500, Loss: 0.4077, Accuracy: 81.02%
# Epoch 93/500, Loss: 0.4238, Accuracy: 79.86%
# Epoch 94/500, Loss: 0.4298, Accuracy: 78.09%
# Epoch 95/500, Loss: 0.3979, Accuracy: 80.40%
# Epoch 96/500, Loss: 0.4228, Accuracy: 78.86%
# Epoch 97/500, Loss: 0.4207, Accuracy: 78.32%
# Epoch 98/500, Loss: 0.4174, Accuracy: 79.55%
# Epoch 99/500, Loss: 0.4100, Accuracy: 79.09%
# Epoch 100/500, Loss: 0.4349, Accuracy: 76.31%
# Epoch 101/500, Loss: 0.4194, Accuracy: 79.09%
# Epoch 102/500, Loss: 0.4107, Accuracy: 80.25%
# Epoch 103/500, Loss: 0.3958, Accuracy: 80.56%
# Epoch 104/500, Loss: 0.4003, Accuracy: 80.63%
# Epoch 105/500, Loss: 0.4053, Accuracy: 79.86%
# Epoch 106/500, Loss: 0.4056, Accuracy: 80.48%
# Epoch 107/500, Loss: 0.3971, Accuracy: 79.40%
# Epoch 108/500, Loss: 0.4057, Accuracy: 79.86%
# Epoch 109/500, Loss: 0.4162, Accuracy: 80.17%
# Epoch 110/500, Loss: 0.4005, Accuracy: 80.86%
# Epoch 111/500, Loss: 0.3960, Accuracy: 80.71%
# Epoch 112/500, Loss: 0.3944, Accuracy: 81.10%
# Epoch 113/500, Loss: 0.3805, Accuracy: 81.64%
# Epoch 114/500, Loss: 0.3864, Accuracy: 80.17%
# Epoch 115/500, Loss: 0.3793, Accuracy: 82.10%
# Epoch 116/500, Loss: 0.3919, Accuracy: 81.64%
# Epoch 117/500, Loss: 0.4005, Accuracy: 79.94%
# Epoch 118/500, Loss: 0.3848, Accuracy: 81.33%
# Epoch 119/500, Loss: 0.4003, Accuracy: 79.32%
# Epoch 120/500, Loss: 0.3998, Accuracy: 79.78%
# Epoch 121/500, Loss: 0.4020, Accuracy: 81.10%
# Epoch 122/500, Loss: 0.3829, Accuracy: 81.71%
# Epoch 123/500, Loss: 0.4074, Accuracy: 81.17%
# Epoch 124/500, Loss: 0.3915, Accuracy: 80.63%
# Epoch 125/500, Loss: 0.3965, Accuracy: 79.55%
# Epoch 126/500, Loss: 0.3889, Accuracy: 81.94%
# Epoch 127/500, Loss: 0.3929, Accuracy: 81.25%
# Epoch 128/500, Loss: 0.3831, Accuracy: 81.64%
# Epoch 129/500, Loss: 0.3936, Accuracy: 81.10%
# Epoch 130/500, Loss: 0.3784, Accuracy: 81.94%
# Epoch 131/500, Loss: 0.3888, Accuracy: 80.86%
# Epoch 132/500, Loss: 0.3987, Accuracy: 80.40%
# Epoch 133/500, Loss: 0.3883, Accuracy: 80.25%
# Epoch 134/500, Loss: 0.4019, Accuracy: 80.09%
# Epoch 135/500, Loss: 0.3700, Accuracy: 81.71%
# Epoch 136/500, Loss: 0.3813, Accuracy: 81.48%
# Epoch 137/500, Loss: 0.3870, Accuracy: 80.32%
# Epoch 138/500, Loss: 0.4060, Accuracy: 80.32%
# Epoch 139/500, Loss: 0.3787, Accuracy: 83.10%
# Epoch 140/500, Loss: 0.3859, Accuracy: 81.25%
# Epoch 141/500, Loss: 0.3728, Accuracy: 82.48%
# Epoch 142/500, Loss: 0.3691, Accuracy: 81.56%
# Epoch 143/500, Loss: 0.3690, Accuracy: 83.41%
# Epoch 144/500, Loss: 0.3652, Accuracy: 83.87%
# Epoch 145/500, Loss: 0.3800, Accuracy: 81.40%
# Epoch 146/500, Loss: 0.3812, Accuracy: 82.10%
# Epoch 147/500, Loss: 0.3998, Accuracy: 80.86%
# Epoch 148/500, Loss: 0.3702, Accuracy: 82.48%
# Epoch 149/500, Loss: 0.3782, Accuracy: 82.87%
# Epoch 150/500, Loss: 0.3817, Accuracy: 81.48%
# Epoch 151/500, Loss: 0.3603, Accuracy: 82.56%
# Epoch 152/500, Loss: 0.3688, Accuracy: 84.41%
# Epoch 153/500, Loss: 0.3886, Accuracy: 82.10%
# Epoch 154/500, Loss: 0.3677, Accuracy: 83.64%
# Epoch 155/500, Loss: 0.3660, Accuracy: 83.10%
# Epoch 156/500, Loss: 0.3769, Accuracy: 82.48%
# Epoch 157/500, Loss: 0.3885, Accuracy: 81.56%
# Epoch 158/500, Loss: 0.3823, Accuracy: 83.10%
# Epoch 159/500, Loss: 0.3717, Accuracy: 83.49%
# Epoch 160/500, Loss: 0.3597, Accuracy: 83.02%
# Epoch 161/500, Loss: 0.3753, Accuracy: 81.48%
# Epoch 162/500, Loss: 0.3792, Accuracy: 82.10%
# Epoch 163/500, Loss: 0.3385, Accuracy: 84.72%
# Epoch 164/500, Loss: 0.3575, Accuracy: 84.10%
# Epoch 165/500, Loss: 0.3743, Accuracy: 82.56%
# Epoch 166/500, Loss: 0.3558, Accuracy: 83.72%
# Epoch 167/500, Loss: 0.3528, Accuracy: 83.95%
# Epoch 168/500, Loss: 0.3433, Accuracy: 85.03%
# Epoch 169/500, Loss: 0.3688, Accuracy: 80.79%
# Epoch 170/500, Loss: 0.3711, Accuracy: 82.64%
# Epoch 171/500, Loss: 0.3664, Accuracy: 82.87%
# Epoch 172/500, Loss: 0.3505, Accuracy: 83.64%
# Epoch 173/500, Loss: 0.3697, Accuracy: 83.18%
# Epoch 174/500, Loss: 0.3601, Accuracy: 83.02%
# Epoch 175/500, Loss: 0.3512, Accuracy: 84.41%
# Epoch 176/500, Loss: 0.3593, Accuracy: 83.10%
# Epoch 177/500, Loss: 0.3541, Accuracy: 83.02%
# Epoch 178/500, Loss: 0.3598, Accuracy: 83.18%
# Epoch 179/500, Loss: 0.3366, Accuracy: 84.41%
# Epoch 180/500, Loss: 0.3602, Accuracy: 83.87%
# Epoch 181/500, Loss: 0.3342, Accuracy: 84.57%
# Epoch 182/500, Loss: 0.3460, Accuracy: 83.10%
# Epoch 183/500, Loss: 0.3490, Accuracy: 84.34%
# Epoch 184/500, Loss: 0.3397, Accuracy: 84.18%
# Epoch 185/500, Loss: 0.3384, Accuracy: 83.95%
# Epoch 186/500, Loss: 0.3350, Accuracy: 85.11%
# Epoch 187/500, Loss: 0.3453, Accuracy: 85.19%
# Epoch 188/500, Loss: 0.3576, Accuracy: 83.72%
# Epoch 189/500, Loss: 0.3503, Accuracy: 84.03%
# Epoch 190/500, Loss: 0.3144, Accuracy: 84.88%
# Epoch 191/500, Loss: 0.3385, Accuracy: 84.10%
# Epoch 192/500, Loss: 0.3543, Accuracy: 84.34%
# Epoch 193/500, Loss: 0.3414, Accuracy: 84.88%
# Epoch 194/500, Loss: 0.3388, Accuracy: 84.72%
# Epoch 195/500, Loss: 0.3537, Accuracy: 83.80%
# Epoch 196/500, Loss: 0.3480, Accuracy: 82.48%
# Epoch 197/500, Loss: 0.3380, Accuracy: 84.34%
# Epoch 198/500, Loss: 0.3493, Accuracy: 84.18%
# Epoch 199/500, Loss: 0.3504, Accuracy: 84.41%
# Epoch 200/500, Loss: 0.3352, Accuracy: 85.11%
# Epoch 201/500, Loss: 0.3253, Accuracy: 85.19%
# Epoch 202/500, Loss: 0.3400, Accuracy: 85.11%
# Epoch 203/500, Loss: 0.3163, Accuracy: 84.57%
# Epoch 204/500, Loss: 0.3438, Accuracy: 83.64%
# Epoch 205/500, Loss: 0.3311, Accuracy: 85.19%
# Epoch 206/500, Loss: 0.3404, Accuracy: 82.72%
# Epoch 207/500, Loss: 0.3265, Accuracy: 84.80%
# Epoch 208/500, Loss: 0.3288, Accuracy: 85.88%
# Epoch 209/500, Loss: 0.3366, Accuracy: 84.10%
# Epoch 210/500, Loss: 0.3301, Accuracy: 85.42%
# Epoch 211/500, Loss: 0.3312, Accuracy: 84.80%
# Epoch 212/500, Loss: 0.3171, Accuracy: 86.03%
# Epoch 213/500, Loss: 0.3400, Accuracy: 84.49%
# Epoch 214/500, Loss: 0.3232, Accuracy: 84.65%
# Epoch 215/500, Loss: 0.3254, Accuracy: 84.95%
# Epoch 216/500, Loss: 0.3192, Accuracy: 86.57%
# Epoch 217/500, Loss: 0.3295, Accuracy: 84.41%
# Epoch 218/500, Loss: 0.3264, Accuracy: 85.96%
# Epoch 219/500, Loss: 0.3423, Accuracy: 84.26%
# Epoch 220/500, Loss: 0.3224, Accuracy: 85.34%
# Epoch 221/500, Loss: 0.3336, Accuracy: 84.49%
# Epoch 222/500, Loss: 0.3194, Accuracy: 86.27%
# Epoch 223/500, Loss: 0.3147, Accuracy: 85.96%
# Epoch 224/500, Loss: 0.3355, Accuracy: 85.96%
# Epoch 225/500, Loss: 0.3177, Accuracy: 86.03%
# Epoch 226/500, Loss: 0.3324, Accuracy: 85.42%
# Epoch 227/500, Loss: 0.3129, Accuracy: 85.11%
# Epoch 228/500, Loss: 0.3188, Accuracy: 85.49%
# Epoch 229/500, Loss: 0.3110, Accuracy: 86.19%
# Epoch 230/500, Loss: 0.3129, Accuracy: 86.27%
# Epoch 231/500, Loss: 0.3092, Accuracy: 85.34%
# Epoch 232/500, Loss: 0.3035, Accuracy: 86.57%
# Epoch 233/500, Loss: 0.3094, Accuracy: 87.19%
# Epoch 234/500, Loss: 0.3077, Accuracy: 86.50%
# Epoch 235/500, Loss: 0.3025, Accuracy: 86.65%
# Epoch 236/500, Loss: 0.3274, Accuracy: 86.03%
# Epoch 237/500, Loss: 0.3269, Accuracy: 85.57%
# Epoch 238/500, Loss: 0.3088, Accuracy: 87.04%
# Epoch 239/500, Loss: 0.3158, Accuracy: 85.34%
# Epoch 240/500, Loss: 0.3125, Accuracy: 86.11%
# Epoch 241/500, Loss: 0.3152, Accuracy: 86.27%
# Epoch 242/500, Loss: 0.3249, Accuracy: 85.65%
# Epoch 243/500, Loss: 0.3131, Accuracy: 86.42%
# Epoch 244/500, Loss: 0.3000, Accuracy: 85.88%
# Epoch 245/500, Loss: 0.3041, Accuracy: 86.88%
# Epoch 246/500, Loss: 0.2893, Accuracy: 87.04%
# Epoch 247/500, Loss: 0.2806, Accuracy: 88.12%
# Epoch 248/500, Loss: 0.3296, Accuracy: 85.49%
# Epoch 249/500, Loss: 0.3068, Accuracy: 86.42%
# Epoch 250/500, Loss: 0.2977, Accuracy: 87.04%
# Epoch 251/500, Loss: 0.3024, Accuracy: 86.11%
# Epoch 252/500, Loss: 0.3130, Accuracy: 85.96%
# Epoch 253/500, Loss: 0.2794, Accuracy: 87.58%
# Epoch 254/500, Loss: 0.3063, Accuracy: 85.73%
# Epoch 255/500, Loss: 0.2982, Accuracy: 87.04%
# Epoch 256/500, Loss: 0.3103, Accuracy: 87.11%
# Epoch 257/500, Loss: 0.3101, Accuracy: 86.73%
# Epoch 258/500, Loss: 0.3062, Accuracy: 86.27%
# Epoch 259/500, Loss: 0.3166, Accuracy: 85.19%
# Epoch 260/500, Loss: 0.3063, Accuracy: 86.27%
# Epoch 261/500, Loss: 0.3167, Accuracy: 86.11%
# Epoch 262/500, Loss: 0.2855, Accuracy: 86.65%
# Epoch 263/500, Loss: 0.3033, Accuracy: 86.42%
# Epoch 264/500, Loss: 0.2955, Accuracy: 86.88%
# Epoch 265/500, Loss: 0.3024, Accuracy: 85.65%
# Epoch 266/500, Loss: 0.3023, Accuracy: 87.19%
# Epoch 267/500, Loss: 0.2993, Accuracy: 87.50%
# Epoch 268/500, Loss: 0.3007, Accuracy: 87.04%
# Epoch 269/500, Loss: 0.3088, Accuracy: 85.73%
# Epoch 270/500, Loss: 0.2847, Accuracy: 87.27%
# Epoch 271/500, Loss: 0.3015, Accuracy: 85.57%
# Epoch 272/500, Loss: 0.3074, Accuracy: 86.19%
# Epoch 273/500, Loss: 0.2918, Accuracy: 87.50%
# Epoch 274/500, Loss: 0.3053, Accuracy: 86.81%
# Epoch 275/500, Loss: 0.3081, Accuracy: 85.49%
# Epoch 276/500, Loss: 0.3032, Accuracy: 86.57%
# Epoch 277/500, Loss: 0.3075, Accuracy: 84.65%
# Epoch 278/500, Loss: 0.3035, Accuracy: 86.03%
# Epoch 279/500, Loss: 0.3065, Accuracy: 85.80%
# Epoch 280/500, Loss: 0.2950, Accuracy: 87.27%
# Epoch 281/500, Loss: 0.2984, Accuracy: 86.42%
# Epoch 282/500, Loss: 0.2994, Accuracy: 86.81%
# Epoch 283/500, Loss: 0.2912, Accuracy: 87.11%
# Epoch 284/500, Loss: 0.2751, Accuracy: 87.50%
# Epoch 285/500, Loss: 0.3017, Accuracy: 87.04%
# Epoch 286/500, Loss: 0.2781, Accuracy: 88.19%
# Epoch 287/500, Loss: 0.2880, Accuracy: 88.12%
# Epoch 288/500, Loss: 0.2934, Accuracy: 86.88%
# Epoch 289/500, Loss: 0.2795, Accuracy: 88.19%
# Epoch 290/500, Loss: 0.2999, Accuracy: 86.96%
# Epoch 291/500, Loss: 0.2752, Accuracy: 87.73%
# Epoch 292/500, Loss: 0.2811, Accuracy: 87.35%
# Epoch 293/500, Loss: 0.2717, Accuracy: 89.20%
# Epoch 294/500, Loss: 0.2777, Accuracy: 87.65%
# Epoch 295/500, Loss: 0.2928, Accuracy: 87.96%
# Epoch 296/500, Loss: 0.3023, Accuracy: 86.34%
# Epoch 297/500, Loss: 0.2953, Accuracy: 87.65%
# Epoch 298/500, Loss: 0.3044, Accuracy: 86.81%
# Epoch 299/500, Loss: 0.2776, Accuracy: 88.50%
# Epoch 300/500, Loss: 0.2728, Accuracy: 88.12%
# Epoch 301/500, Loss: 0.2695, Accuracy: 88.50%
# Epoch 302/500, Loss: 0.2764, Accuracy: 87.89%
# Epoch 303/500, Loss: 0.2900, Accuracy: 87.04%
# Epoch 304/500, Loss: 0.3210, Accuracy: 85.88%
# Epoch 305/500, Loss: 0.3035, Accuracy: 85.80%
# Epoch 306/500, Loss: 0.2891, Accuracy: 86.50%
# Epoch 307/500, Loss: 0.2955, Accuracy: 87.50%
# Epoch 308/500, Loss: 0.2748, Accuracy: 87.89%
# Epoch 309/500, Loss: 0.2875, Accuracy: 86.96%
# Epoch 310/500, Loss: 0.2815, Accuracy: 87.65%
# Epoch 311/500, Loss: 0.2928, Accuracy: 86.34%
# Epoch 312/500, Loss: 0.2787, Accuracy: 86.73%
# Epoch 313/500, Loss: 0.2702, Accuracy: 88.97%
# Epoch 314/500, Loss: 0.2862, Accuracy: 88.04%
# Epoch 315/500, Loss: 0.2837, Accuracy: 87.50%
# Epoch 316/500, Loss: 0.2899, Accuracy: 86.50%
# Epoch 317/500, Loss: 0.2747, Accuracy: 87.50%
# Epoch 318/500, Loss: 0.2886, Accuracy: 88.19%
# Epoch 319/500, Loss: 0.2636, Accuracy: 88.89%
# Epoch 320/500, Loss: 0.2729, Accuracy: 88.97%
# Epoch 321/500, Loss: 0.3063, Accuracy: 86.81%
# Epoch 322/500, Loss: 0.2769, Accuracy: 88.43%
# Epoch 323/500, Loss: 0.2855, Accuracy: 87.27%
# Epoch 324/500, Loss: 0.2782, Accuracy: 87.81%
# Epoch 325/500, Loss: 0.2682, Accuracy: 88.73%
# Epoch 326/500, Loss: 0.2651, Accuracy: 88.73%
# Epoch 327/500, Loss: 0.2804, Accuracy: 88.04%
# Epoch 328/500, Loss: 0.2808, Accuracy: 88.27%
# Epoch 329/500, Loss: 0.2793, Accuracy: 87.73%
# Epoch 330/500, Loss: 0.2861, Accuracy: 86.65%
# Epoch 331/500, Loss: 0.2906, Accuracy: 87.04%
# Epoch 332/500, Loss: 0.2693, Accuracy: 87.27%
# Epoch 333/500, Loss: 0.2591, Accuracy: 88.50%
# Epoch 334/500, Loss: 0.2754, Accuracy: 88.04%
# Epoch 335/500, Loss: 0.2762, Accuracy: 87.35%
# Epoch 336/500, Loss: 0.2498, Accuracy: 89.97%
# Epoch 337/500, Loss: 0.2733, Accuracy: 88.73%
# Epoch 338/500, Loss: 0.2841, Accuracy: 88.04%
# Epoch 339/500, Loss: 0.2880, Accuracy: 87.19%
# Epoch 340/500, Loss: 0.2656, Accuracy: 89.27%
# Epoch 341/500, Loss: 0.2796, Accuracy: 87.96%
# Epoch 342/500, Loss: 0.2670, Accuracy: 88.50%
# Epoch 343/500, Loss: 0.2671, Accuracy: 88.19%
# Epoch 344/500, Loss: 0.2606, Accuracy: 88.81%
# Epoch 345/500, Loss: 0.2662, Accuracy: 88.19%
# Epoch 346/500, Loss: 0.2603, Accuracy: 89.04%
# Epoch 347/500, Loss: 0.2830, Accuracy: 87.11%
# Epoch 348/500, Loss: 0.2811, Accuracy: 87.50%
# Epoch 349/500, Loss: 0.2869, Accuracy: 86.50%
# Epoch 350/500, Loss: 0.2806, Accuracy: 87.42%
# Epoch 351/500, Loss: 0.2591, Accuracy: 89.97%
# Epoch 352/500, Loss: 0.2734, Accuracy: 87.81%
# Epoch 353/500, Loss: 0.2636, Accuracy: 88.66%
# Epoch 354/500, Loss: 0.2868, Accuracy: 87.96%
# Epoch 355/500, Loss: 0.3047, Accuracy: 86.57%
# Epoch 356/500, Loss: 0.2680, Accuracy: 88.35%
# Epoch 357/500, Loss: 0.2767, Accuracy: 87.73%
# Epoch 358/500, Loss: 0.2730, Accuracy: 89.27%
# Epoch 359/500, Loss: 0.2758, Accuracy: 87.50%
# Epoch 360/500, Loss: 0.2748, Accuracy: 87.58%
# Epoch 361/500, Loss: 0.2936, Accuracy: 87.19%
# Epoch 362/500, Loss: 0.2788, Accuracy: 88.27%
# Epoch 363/500, Loss: 0.2596, Accuracy: 88.97%
# Epoch 364/500, Loss: 0.2619, Accuracy: 89.12%
# Epoch 365/500, Loss: 0.2680, Accuracy: 87.89%
# Epoch 366/500, Loss: 0.2574, Accuracy: 88.81%
# Epoch 367/500, Loss: 0.2651, Accuracy: 88.89%
# Epoch 368/500, Loss: 0.2776, Accuracy: 87.58%
# Epoch 369/500, Loss: 0.2497, Accuracy: 90.12%
# Epoch 370/500, Loss: 0.2449, Accuracy: 90.05%
# Epoch 371/500, Loss: 0.2589, Accuracy: 89.43%
# Epoch 372/500, Loss: 0.2718, Accuracy: 88.66%
# Epoch 373/500, Loss: 0.2852, Accuracy: 87.58%
# Epoch 374/500, Loss: 0.2732, Accuracy: 88.81%
# Epoch 375/500, Loss: 0.2653, Accuracy: 87.89%
# Epoch 376/500, Loss: 0.2621, Accuracy: 88.19%
# Epoch 377/500, Loss: 0.2676, Accuracy: 87.27%
# Epoch 378/500, Loss: 0.2542, Accuracy: 88.66%
# Epoch 379/500, Loss: 0.2791, Accuracy: 87.96%
# Epoch 380/500, Loss: 0.2643, Accuracy: 88.43%
# Epoch 381/500, Loss: 0.2756, Accuracy: 88.66%
# Epoch 382/500, Loss: 0.2678, Accuracy: 88.12%
# Epoch 383/500, Loss: 0.2587, Accuracy: 89.27%
# Epoch 384/500, Loss: 0.2314, Accuracy: 89.74%
# Epoch 385/500, Loss: 0.2429, Accuracy: 89.27%
# Epoch 386/500, Loss: 0.2672, Accuracy: 88.35%
# Epoch 387/500, Loss: 0.2571, Accuracy: 89.43%
# Epoch 388/500, Loss: 0.2571, Accuracy: 88.50%
# Epoch 389/500, Loss: 0.2758, Accuracy: 88.50%
# Epoch 390/500, Loss: 0.2813, Accuracy: 87.42%
# Epoch 391/500, Loss: 0.2581, Accuracy: 89.35%
# Epoch 392/500, Loss: 0.2648, Accuracy: 88.43%
# Epoch 393/500, Loss: 0.2555, Accuracy: 89.27%
# Epoch 394/500, Loss: 0.2484, Accuracy: 88.89%
# Epoch 395/500, Loss: 0.2449, Accuracy: 88.58%
# Epoch 396/500, Loss: 0.2458, Accuracy: 89.27%
# Epoch 397/500, Loss: 0.2453, Accuracy: 89.27%
# Epoch 398/500, Loss: 0.2478, Accuracy: 89.58%
# Epoch 399/500, Loss: 0.2523, Accuracy: 88.50%
# Epoch 400/500, Loss: 0.2525, Accuracy: 88.35%
# Epoch 401/500, Loss: 0.2541, Accuracy: 89.20%
# Epoch 402/500, Loss: 0.2731, Accuracy: 87.27%
# Epoch 403/500, Loss: 0.2653, Accuracy: 87.81%
# Epoch 404/500, Loss: 0.2855, Accuracy: 87.58%
# Epoch 405/500, Loss: 0.2749, Accuracy: 87.81%
# Epoch 406/500, Loss: 0.2881, Accuracy: 87.73%
# Epoch 407/500, Loss: 0.2761, Accuracy: 87.89%
# Epoch 408/500, Loss: 0.2632, Accuracy: 88.81%
# Epoch 409/500, Loss: 0.2559, Accuracy: 89.51%
# Epoch 410/500, Loss: 0.2437, Accuracy: 89.81%
# Epoch 411/500, Loss: 0.2723, Accuracy: 88.35%
# Epoch 412/500, Loss: 0.2596, Accuracy: 88.50%
# Epoch 413/500, Loss: 0.2439, Accuracy: 89.20%
# Epoch 414/500, Loss: 0.2614, Accuracy: 88.12%
# Epoch 415/500, Loss: 0.2701, Accuracy: 88.81%
# Epoch 416/500, Loss: 0.2646, Accuracy: 88.73%
# Epoch 417/500, Loss: 0.2422, Accuracy: 89.97%
# Epoch 418/500, Loss: 0.2435, Accuracy: 88.81%
# Epoch 419/500, Loss: 0.2624, Accuracy: 89.58%
# Epoch 420/500, Loss: 0.2644, Accuracy: 89.04%
# Epoch 421/500, Loss: 0.2517, Accuracy: 88.89%
# Epoch 422/500, Loss: 0.2472, Accuracy: 89.20%
# Epoch 423/500, Loss: 0.2392, Accuracy: 89.12%
# Epoch 424/500, Loss: 0.2495, Accuracy: 89.58%
# Epoch 425/500, Loss: 0.2338, Accuracy: 90.43%
# Epoch 426/500, Loss: 0.2337, Accuracy: 89.51%
# Epoch 427/500, Loss: 0.2437, Accuracy: 89.89%
# Epoch 428/500, Loss: 0.2366, Accuracy: 89.43%
# Epoch 429/500, Loss: 0.2389, Accuracy: 89.12%
# Epoch 430/500, Loss: 0.2752, Accuracy: 88.27%
# Epoch 431/500, Loss: 0.2420, Accuracy: 89.43%
# Epoch 432/500, Loss: 0.2493, Accuracy: 89.04%
# Epoch 433/500, Loss: 0.2630, Accuracy: 88.19%
# Epoch 434/500, Loss: 0.2507, Accuracy: 89.51%
# Epoch 435/500, Loss: 0.2619, Accuracy: 89.35%
# Epoch 436/500, Loss: 0.2640, Accuracy: 88.66%
# Epoch 437/500, Loss: 0.2471, Accuracy: 90.20%
# Epoch 438/500, Loss: 0.2724, Accuracy: 87.27%
# Epoch 439/500, Loss: 0.2576, Accuracy: 88.66%
# Epoch 440/500, Loss: 0.2661, Accuracy: 88.19%
# Epoch 441/500, Loss: 0.2698, Accuracy: 88.81%
# Epoch 442/500, Loss: 0.2516, Accuracy: 88.27%
# Epoch 443/500, Loss: 0.2488, Accuracy: 88.35%
# Epoch 444/500, Loss: 0.2664, Accuracy: 88.43%
# Epoch 445/500, Loss: 0.2477, Accuracy: 89.58%
# Epoch 446/500, Loss: 0.2475, Accuracy: 89.81%
# Epoch 447/500, Loss: 0.2497, Accuracy: 89.27%
# Epoch 448/500, Loss: 0.2297, Accuracy: 90.05%
# Epoch 449/500, Loss: 0.2279, Accuracy: 90.82%
# Epoch 450/500, Loss: 0.2422, Accuracy: 90.20%
# Epoch 451/500, Loss: 0.2732, Accuracy: 87.42%
# Epoch 452/500, Loss: 0.2678, Accuracy: 88.27%
# Epoch 453/500, Loss: 0.2468, Accuracy: 89.89%
# Epoch 454/500, Loss: 0.2669, Accuracy: 88.89%
# Epoch 455/500, Loss: 0.2638, Accuracy: 88.73%
# Epoch 456/500, Loss: 0.2468, Accuracy: 90.35%
# Epoch 457/500, Loss: 0.2549, Accuracy: 89.51%
# Epoch 458/500, Loss: 0.2455, Accuracy: 90.35%
# Epoch 459/500, Loss: 0.2424, Accuracy: 89.97%
# Epoch 460/500, Loss: 0.2434, Accuracy: 89.58%
# Epoch 461/500, Loss: 0.2465, Accuracy: 88.89%
# Epoch 462/500, Loss: 0.2494, Accuracy: 89.74%
# Epoch 463/500, Loss: 0.2443, Accuracy: 89.66%
# Epoch 464/500, Loss: 0.2314, Accuracy: 90.43%
# Epoch 465/500, Loss: 0.2568, Accuracy: 88.35%
# Epoch 466/500, Loss: 0.2369, Accuracy: 90.12%
# Epoch 467/500, Loss: 0.2586, Accuracy: 88.19%
# Epoch 468/500, Loss: 0.2606, Accuracy: 88.58%
# Epoch 469/500, Loss: 0.2597, Accuracy: 89.81%
# Epoch 470/500, Loss: 0.2567, Accuracy: 87.81%
# Epoch 471/500, Loss: 0.2328, Accuracy: 90.12%
# Epoch 472/500, Loss: 0.2530, Accuracy: 88.97%
# Epoch 473/500, Loss: 0.2289, Accuracy: 91.44%
# Epoch 474/500, Loss: 0.2583, Accuracy: 89.20%
# Epoch 475/500, Loss: 0.2334, Accuracy: 90.05%
# Epoch 476/500, Loss: 0.2461, Accuracy: 90.05%
# Epoch 477/500, Loss: 0.2395, Accuracy: 89.97%
# Epoch 478/500, Loss: 0.2154, Accuracy: 91.90%
# Epoch 479/500, Loss: 0.2298, Accuracy: 90.59%
# Epoch 480/500, Loss: 0.2258, Accuracy: 90.35%
# Epoch 481/500, Loss: 0.2321, Accuracy: 90.90%
# Epoch 482/500, Loss: 0.2290, Accuracy: 90.97%
# Epoch 483/500, Loss: 0.2397, Accuracy: 90.43%
# Epoch 484/500, Loss: 0.2543, Accuracy: 90.51%
# Epoch 485/500, Loss: 0.2454, Accuracy: 89.51%
# Epoch 486/500, Loss: 0.2350, Accuracy: 89.51%
# Epoch 487/500, Loss: 0.2523, Accuracy: 89.74%
# Epoch 488/500, Loss: 0.2389, Accuracy: 90.43%
# Epoch 489/500, Loss: 0.2292, Accuracy: 90.43%
# Epoch 490/500, Loss: 0.2363, Accuracy: 89.74%
# Epoch 491/500, Loss: 0.2465, Accuracy: 90.28%
# Epoch 492/500, Loss: 0.2301, Accuracy: 90.97%
# Epoch 493/500, Loss: 0.2310, Accuracy: 90.35%
# Epoch 494/500, Loss: 0.2277, Accuracy: 90.12%
# Epoch 495/500, Loss: 0.2581, Accuracy: 89.81%
# Epoch 496/500, Loss: 0.2446, Accuracy: 89.27%
# Epoch 497/500, Loss: 0.2534, Accuracy: 88.89%
# Epoch 498/500, Loss: 0.2463, Accuracy: 90.28%
# Epoch 499/500, Loss: 0.2307, Accuracy: 89.66%
# Epoch 500/500, Loss: 0.2304, Accuracy: 89.66%
# Average Loss: 0.23038062821199864
# Highest Train Accuracy: 0.9189814814814815

# %% [markdown]
# ##Evaluating Model

# %%
classes_list = ['Left', 'Right']
eval_model = EvalModel(trained_eegnet_model)
test_accuracy = eval_model.test_model(test_dataset)
eval_model.plot_confusion_matrix(test_dataset, classes_list)
# Out:
# /------------------------------/
# Test Accuracy: 79.32%
# /------------------------------/

# %%
#f1스코어 알아내기 위한 코드 삽입
from sklearn.metrics import f1_score, classification_report
from torch.utils.data import DataLoader
import torch
import numpy as np

def get_predictions(model, dataset, batch_size=64):
    model.eval()
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    y_true = []
    y_pred = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)
            y = y.to(device)

            outputs = model(X)
            preds = torch.argmax(outputs, dim=1)

            y_true.extend(y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    return np.array(y_true), np.array(y_pred)


y_true, y_pred = get_predictions(trained_eegnet_model, test_dataset)

macro_f1 = f1_score(y_true, y_pred, average='macro')
weighted_f1 = f1_score(y_true, y_pred, average='weighted')

print("Macro F1:", macro_f1)
print("Weighted F1:", weighted_f1)

print(classification_report(y_true, y_pred, target_names=classes_list))
# Out:
# Macro F1: 0.790625
# Weighted F1: 0.790625
#               precision    recall  f1-score   support
#
#         Left       0.88      0.68      0.77       648
#        Right       0.74      0.90      0.81       648
#
#     accuracy                           0.79      1296
#    macro avg       0.81      0.79      0.79      1296
# weighted avg       0.81      0.79      0.79      1296

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

print("Unique y_true:", np.unique(y_true, return_counts=True))
print("Unique y_pred:", np.unique(y_pred, return_counts=True))

cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# Unique y_true: (array([0, 1]), array([648, 648]))
# Unique y_pred: (array([0, 1]), array([504, 792]))
# [[442 206]
#  [ 62 586]]

# %%
print("Train data shape:", train_dataset.tensors[0].shape)
print("Train label shape:", train_dataset.tensors[1].shape)

print("Test data shape:", test_dataset.tensors[0].shape)
print("Test label shape:", test_dataset.tensors[1].shape)
# Out:
# Train data shape: torch.Size([1296, 1, 22, 1001])
# Train label shape: torch.Size([1296])
# Test data shape: torch.Size([1296, 1, 22, 1001])
# Test label shape: torch.Size([1296])
