# %% [markdown]
# <a href="https://colab.research.google.com/github/hongsua05/baekjoon/blob/main/EEGNet_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motor Imagery Task Classification

# %% [markdown]
# #Extracting Data

# %% [markdown]
# ##Downloading BCI Competition IV 2a Dataset

# %%
# !wget https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# Out:
# --2026-05-18 07:13:02--  https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# Resolving www.bbci.de (www.bbci.de)... 141.23.71.83
# Connecting to www.bbci.de (www.bbci.de)|141.23.71.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 439968864 (420M) [application/zip]
# Saving to: ‘BCICIV_2a_gdf.zip’
#
# BCICIV_2a_gdf.zip   100%[===================>] 419.59M  21.2MB/s    in 22s
#
# 2026-05-18 07:13:25 (18.9 MB/s) - ‘BCICIV_2a_gdf.zip’ saved [439968864/439968864]

# %%
# !mkdir -p /content/cleaned_data/

# %%
# %%capture
# !unzip /content/BCICIV_2a_gdf.zip -d raw_data

# %% [markdown]
# #Installing Packages

# %%
# %%capture
# !pip install mne

# %%
# %%capture
# !pip install torch-summary

# %% [markdown]
# #Libraries Used

# %%
import os
import mne
import math
import copy
import gdown
import random
import scipy.io
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Building Dataset

# %%
# !mkdir -p /content/cleaned_data/first_session
# !mkdir -p /content/cleaned_data/second_session

# %% [markdown]
# ##First Session

# %%
raw_data_folder = '/content/raw_data/'
cleaned_data_folder = '/content/cleaned_data/first_session/'
files = os.listdir(raw_data_folder)

# Selecting files with suffix 'T.gdf'
filtered_files = [file for file in files if file.endswith('T.gdf')]

raw_list = []

# Iterating through filtered files
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Reading raw data
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
    # Droping EOG channels
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # High Pass Filtering 4-40 Hz
    raw.filter(l_freq=4, h_freq=40, method='iir')

    # Notch filter for Removal of Line Voltage
    raw.notch_filter(freqs=50)

    # Saving the modified raw data to a file with .fif suffix
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)
    # Appending data to the list
    raw_list.append(raw)

final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'First_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting GDF parameters from /content/raw_data/A09T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A09T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A09T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A09T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A05T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A05T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A05T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A05T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A07T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A07T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A07T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A07T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A04T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 600914  =      0.000 ...  2403.656 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A04T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A04T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A04T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A06T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A06T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A06T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A06T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A03T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A03T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A03T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A03T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A02T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A02T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A02T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A02T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A01T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A01T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A01T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A01T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A08T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A08T.fif
# /tmp/ipykernel_2754/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A08T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A08T.fif
# [done]
# Writing /content/cleaned_data/first_session/First_Session_Subjects.fif
# /tmp/ipykernel_2754/468050219.py:33: RuntimeWarning: This filename (/content/cleaned_data/first_session/First_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/First_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/first_session/First_Session_Subjects.fif')]

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '769': 7 Cue onset **Left** (class 1) : 0
# '770': 8 Cue onset **Right** (class 2) : 1
# '771': 9 Cue onset **Foot** (class 3) : 2
# '772': 10 Cue onset **Tongue** (class 4): 3

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('769'), np.str_('770'), np.str_('771'), np.str_('772')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('769'): 7,
#  np.str_('770'): 8,
#  np.str_('771'): 9,
#  np.str_('772'): 10}

# %% [markdown]
# **Time choice:**
# [0.s, 4s] Post Cue on set:  [2s, 6s]

# %%
epochs = mne.Epochs(final_raw, events[0], event_id=[7, 8], tmin=0, tmax=4, reject=None, baseline=None, preload=True)
first_session_data = epochs.get_data(copy=True)
first_session_labels = epochs.events[:,-1]
# 7: Left hand → 0
# 8: Right hand → 1
first_session_labels = first_session_labels - 7
first_session_labels = first_session_labels.astype(int)
# Out:
# Not setting metadata
# 1296 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1296 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
print("First_session_dataset shape:",first_session_data.shape)
# Out:
# First_session_dataset shape: (1296, 22, 1001)

# %% [markdown]
# ##Second Session

# %% [markdown]
# ###Extracting Labels for datas with "E.gdf" prefix

# %%
# Replace this with your actual shareable link
shareable_link = 'https://drive.google.com/file/d/11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo/view?usp=drive_link'

# Extract file ID from the shareable link
file_id = shareable_link.split('/d/')[1].split('/view')[0]

# Create the direct download link
download_url = f'https://drive.google.com/uc?id={file_id}&export=download'

# Specify the output file path
output_file = 'true_labels.zip'

# Download the file
gdown.download(download_url, output_file, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo&export=download
# To: /content/true_labels.zip
# 100%|██████████| 7.20k/7.20k [00:00<00:00, 17.0MB/s]
# 'true_labels.zip'

# %%
# %%capture
# !unzip /content/true_labels.zip -d second_session_labels

# %% [markdown]
# ###Extracting datas of second session

# %%
raw_data_folder = '/content/raw_data/'
cleaned_data_folder = '/content/cleaned_data/second_session/'
mat_folder = '/content/second_session_labels/'

# Selecting files with suffix 'E.mat'
mat_files = os.listdir(mat_folder)
filtered_math_labels = [file for file in mat_files if file.endswith('E.mat')]

# Selecting files with suffix 'E.gdf'
files = os.listdir(raw_data_folder)
filtered_files = [file for file in files if file.endswith('E.gdf')]

raw_list = []
second_session_labels = np.array([])
# Iterating through filtered files
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Reading raw data
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
    # Droping EOG channels
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # High Pass Filtering 4-40 Hz
    raw.filter(l_freq=4, h_freq=40, method='iir')

    # Saving the modified raw data to a file with .fif suffix
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)
    # Appending data to t he list
    raw_list.append(raw)

    # Mat files for the labels
    mat_file_name = file.replace('.gdf', '.mat')
    mat_file_path = os.path.join(mat_folder, mat_file_name)
    print(f"data:{file}, label:{mat_file_name}")

    if os.path.exists(mat_file_path):
        mat_data = scipy.io.loadmat(mat_file_path)
        class_labels = mat_data.get('classlabel', [])

        # Check if 'classlabel' key exists and is not empty
        if class_labels.size > 0:
             # Convert to a NumPy array and flatten
            class_labels_array = np.array(class_labels, dtype=int).flatten()
            # Concatenate with the existing test_labels array
            second_session_labels = np.concatenate((second_session_labels, class_labels_array))
        else:
            print(f"Warning: 'classlabel' not found or empty in {mat_file_name}.")
    else:
        print(f"Warning: {mat_file_name} not found.")

final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'Second_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting GDF parameters from /content/raw_data/A06E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 666372  =      0.000 ...  2665.488 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A06E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A06E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A06E.fif
# [done]
# data:A06E.gdf, label:A06E.mat
# Extracting GDF parameters from /content/raw_data/A08E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 687791  =      0.000 ...  2751.164 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A08E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A08E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A08E.fif
# [done]
# data:A08E.gdf, label:A08E.mat
# Extracting GDF parameters from /content/raw_data/A01E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686999  =      0.000 ...  2747.996 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A01E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A01E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A01E.fif
# [done]
# data:A01E.gdf, label:A01E.mat
# Extracting GDF parameters from /content/raw_data/A09E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 675097  =      0.000 ...  2700.388 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A09E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A09E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A09E.fif
# [done]
# data:A09E.gdf, label:A09E.mat
# Extracting GDF parameters from /content/raw_data/A05E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 679862  =      0.000 ...  2719.448 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A05E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A05E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A05E.fif
# [done]
# data:A05E.gdf, label:A05E.mat
# Extracting GDF parameters from /content/raw_data/A02E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 662665  =      0.000 ...  2650.660 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A02E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A02E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A02E.fif
# [done]
# data:A02E.gdf, label:A02E.mat
# Extracting GDF parameters from /content/raw_data/A04E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 660046  =      0.000 ...  2640.184 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A04E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A04E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A04E.fif
# [done]
# data:A04E.gdf, label:A04E.mat
# Extracting GDF parameters from /content/raw_data/A03E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 648774  =      0.000 ...  2595.096 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A03E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A03E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A03E.fif
# [done]
# data:A03E.gdf, label:A03E.mat
# Extracting GDF parameters from /content/raw_data/A07E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 673134  =      0.000 ...  2692.536 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A07E.fif
# /tmp/ipykernel_2754/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A07E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A07E.fif
# [done]
# data:A07E.gdf, label:A07E.mat
# Writing /content/cleaned_data/second_session/Second_Session_Subjects.fif
# /tmp/ipykernel_2754/2108108794.py:55: RuntimeWarning: This filename (/content/cleaned_data/second_session/Second_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/Second_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/second_session/Second_Session_Subjects.fif')]

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '783': 7 Cue unknown

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('783')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('783'): 7}

# %%
epochs = mne.Epochs(final_raw, events[0], event_id=7, tmin=0, tmax=4, reject=None, baseline=None, preload=None)
second_session_data = epochs.get_data(copy=True)
# Second session label은 true label 파일에서 가져온 값: 1,2,3,4
# 1 = left hand, 2 = right hand만 남김
mask = (second_session_labels == 1) | (second_session_labels == 2)

second_session_data = second_session_data[mask]
second_session_labels = second_session_labels[mask]

# 1: left hand → 0
# 2: right hand → 1
second_session_labels = second_session_labels - 1
second_session_labels = second_session_labels.astype(int)
# Out:
# Not setting metadata
# 2592 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2592 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
print("Second Session Dataset shape:",second_session_data.shape)
# Out:
# Second Session Dataset shape: (1296, 22, 1001)

# %% [markdown]
# ###Structuring Data

# %%
2# Choosing Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loss Function
criterion = nn.CrossEntropyLoss()

# Normalizing Labels to [0, 1, 2, 3]
y_train = first_session_labels - np.min(first_session_labels)
y_test = second_session_labels - np.min(second_session_labels)

# Normalizing Input features: z-score(mean=0, std=1)
X_first_session = (first_session_data - np.mean(first_session_data)) / np.std(first_session_data)
X_second_session = (second_session_data - np.mean(second_session_data)) / np.std(second_session_data)

X = np.concatenate((X_first_session, X_second_session))
y = np.concatenate((y_train, y_test))

# Spliting  Data: 90% for Train and 10% for Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# Converting to Tensor
X_train = torch.Tensor(X_train).unsqueeze(1).to(device)
X_test = torch.Tensor(X_test).unsqueeze(1).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test = torch.LongTensor(y_test).to(device)

# Creating Tensor Dataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# Printing the sizes
print("Size of X_train:", X_train.size())
print("Size of X_test:", X_test.size())
print("Size of y_train:", y_train.size())
print("Size of y_test:", y_test.size())
# Out:
# Size of X_train: torch.Size([2332, 1, 22, 1001])
# Size of X_test: torch.Size([260, 1, 22, 1001])
# Size of y_train: torch.Size([2332])
# Size of y_test: torch.Size([260])

# %% [markdown]
# ddaining Class

# %%
class TrainModel():
    def __init__(self,):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def train_model(self, model, train_dataset, learning_rate=0.001, batch_size=64, epochs=500):
        model = model.to(self.device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        highest_train_accuracy = 0.0

        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            correct = 0
            total = 0
            for inputs, labels in train_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            epoch_loss = running_loss / len(train_loader.dataset)
            epoch_accuracy = correct / total
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy
            print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {(epoch_accuracy*100):.2f}%")

        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)
        print("Highest Train Accuracy:", highest_train_accuracy)

        # Saving model
        torch.save(model.state_dict(), 'eegnet_model.pth')
        return model

# %% [markdown]
# #Evaluating Model

# %%
class EvalModel():
    def __init__(self, model):
        self.model = model.to(device)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    def test_model(self, test_dataset):
        self.model.eval()
        correct = 0
        total = 0
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = (correct / total) * 100
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")
        return accuracy

    def plot_confusion_matrix(self, test_dataset, classes):
        self.model.eval()
        y_pred = []
        y_true = []
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                y_pred.append(predicted.item())
                y_true.append(labels.item())

        cf_matrix = confusion_matrix(y_true, y_pred)
        cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]

        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        plt.figure(figsize=(10, 7))
        sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='.2f')
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.savefig('confusion_matrix_model.png')
        plt.show()

# %% [markdown]
# #EEGNet Model

# %%
class EEGNetModel(nn.Module): # EEGNET-8,2
    def __init__(self, chans=22, classes=4, time_points=1001, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, dropout_rate=0.5, max_norm1=1, max_norm2=0.25):
        super(EEGNetModel, self).__init__()
        # Calculating FC input features
        linear_size = (time_points//(pk1*pk2))*f2

        # Temporal Filters
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )
        # Spatial Filters
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False), # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16),  groups=f2, bias=False, padding='same'), # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False), # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(linear_size, classes)

        # Apply max_norm constraint to the depthwise layer in block2
        self._apply_max_norm(self.block2[0], max_norm1)

        # Apply max_norm constraint to the linear layer
        self._apply_max_norm(self.fc, max_norm2)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ##Model Summery

# %%
input_size = (1, 22, 1001)
eegnet_model = EEGNetModel().to(device)
summary(eegnet_model, input_size)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:548: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv2d(
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 4]                   900
# ==========================================================================================
# Total params: 3,812
# Trainable params: 3,812
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.06
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 4]                   900
# ==========================================================================================
# Total params: 3,812
# Trainable params: 3,812
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.06
# ==========================================================================================

# %% [markdown]
# ##Training Model

# %%
eegnet_model = EEGNetModel(chans=22, classes=2, time_points=1001).to(device)

# Training Hyperparameters
EPOCHS = 500
BATCH_SIZE = 64
LEARNING_RATE = 0.001
trainer = TrainModel()
trained_eegnet_model = trainer.train_model(eegnet_model, train_dataset, learning_rate=LEARNING_RATE,
                                   batch_size=BATCH_SIZE, epochs=EPOCHS)
torch.save(trained_eegnet_model.state_dict(), 'eegnet_model.pth')
# Out:
# Epoch 1/500, Loss: 0.6936, Accuracy: 50.69%
# Epoch 2/500, Loss: 0.6888, Accuracy: 52.19%
# Epoch 3/500, Loss: 0.6822, Accuracy: 54.37%
# Epoch 4/500, Loss: 0.6596, Accuracy: 60.33%
# Epoch 5/500, Loss: 0.6230, Accuracy: 61.84%
# Epoch 6/500, Loss: 0.5769, Accuracy: 68.52%
# Epoch 7/500, Loss: 0.5851, Accuracy: 66.64%
# Epoch 8/500, Loss: 0.5589, Accuracy: 69.94%
# Epoch 9/500, Loss: 0.5472, Accuracy: 69.64%
# Epoch 10/500, Loss: 0.5468, Accuracy: 69.55%
# Epoch 11/500, Loss: 0.5310, Accuracy: 70.88%
# Epoch 12/500, Loss: 0.5354, Accuracy: 70.58%
# Epoch 13/500, Loss: 0.5279, Accuracy: 71.83%
# Epoch 14/500, Loss: 0.5297, Accuracy: 71.74%
# Epoch 15/500, Loss: 0.5219, Accuracy: 72.21%
# Epoch 16/500, Loss: 0.5154, Accuracy: 72.04%
# Epoch 17/500, Loss: 0.5192, Accuracy: 71.70%
# Epoch 18/500, Loss: 0.5078, Accuracy: 73.41%
# Epoch 19/500, Loss: 0.5190, Accuracy: 71.87%
# Epoch 20/500, Loss: 0.5116, Accuracy: 73.24%
# Epoch 21/500, Loss: 0.4955, Accuracy: 72.98%
# Epoch 22/500, Loss: 0.5167, Accuracy: 72.47%
# Epoch 23/500, Loss: 0.5021, Accuracy: 73.63%
# Epoch 24/500, Loss: 0.5027, Accuracy: 73.58%
# Epoch 25/500, Loss: 0.5020, Accuracy: 72.56%
# Epoch 26/500, Loss: 0.5008, Accuracy: 73.20%
# Epoch 27/500, Loss: 0.4822, Accuracy: 74.87%
# Epoch 28/500, Loss: 0.4849, Accuracy: 74.83%
# Epoch 29/500, Loss: 0.4823, Accuracy: 74.66%
# Epoch 30/500, Loss: 0.4822, Accuracy: 75.26%
# Epoch 31/500, Loss: 0.4830, Accuracy: 74.79%
# Epoch 32/500, Loss: 0.4797, Accuracy: 75.60%
# Epoch 33/500, Loss: 0.4837, Accuracy: 73.80%
# Epoch 34/500, Loss: 0.4755, Accuracy: 76.11%
# Epoch 35/500, Loss: 0.4694, Accuracy: 75.86%
# Epoch 36/500, Loss: 0.4604, Accuracy: 76.84%
# Epoch 37/500, Loss: 0.4783, Accuracy: 75.26%
# Epoch 38/500, Loss: 0.4730, Accuracy: 76.37%
# Epoch 39/500, Loss: 0.4700, Accuracy: 76.42%
# Epoch 40/500, Loss: 0.4515, Accuracy: 77.66%
# Epoch 41/500, Loss: 0.4554, Accuracy: 77.92%
# Epoch 42/500, Loss: 0.4512, Accuracy: 77.57%
# Epoch 43/500, Loss: 0.4678, Accuracy: 76.11%
# Epoch 44/500, Loss: 0.4442, Accuracy: 78.04%
# Epoch 45/500, Loss: 0.4477, Accuracy: 76.59%
# Epoch 46/500, Loss: 0.4372, Accuracy: 78.47%
# Epoch 47/500, Loss: 0.4402, Accuracy: 78.52%
# Epoch 48/500, Loss: 0.4301, Accuracy: 79.03%
# Epoch 49/500, Loss: 0.4372, Accuracy: 78.47%
# Epoch 50/500, Loss: 0.4294, Accuracy: 79.63%
# Epoch 51/500, Loss: 0.4154, Accuracy: 80.70%
# Epoch 52/500, Loss: 0.4219, Accuracy: 79.76%
# Epoch 53/500, Loss: 0.4108, Accuracy: 80.27%
# Epoch 54/500, Loss: 0.4186, Accuracy: 79.46%
# Epoch 55/500, Loss: 0.4248, Accuracy: 79.07%
# Epoch 56/500, Loss: 0.4106, Accuracy: 81.26%
# Epoch 57/500, Loss: 0.4094, Accuracy: 80.57%
# Epoch 58/500, Loss: 0.4048, Accuracy: 80.87%
# Epoch 59/500, Loss: 0.4067, Accuracy: 81.82%
# Epoch 60/500, Loss: 0.3978, Accuracy: 81.69%
# Epoch 61/500, Loss: 0.3965, Accuracy: 81.52%
# Epoch 62/500, Loss: 0.3944, Accuracy: 80.83%
# Epoch 63/500, Loss: 0.3983, Accuracy: 81.43%
# Epoch 64/500, Loss: 0.3862, Accuracy: 82.72%
# Epoch 65/500, Loss: 0.3980, Accuracy: 81.43%
# Epoch 66/500, Loss: 0.3928, Accuracy: 81.52%
# Epoch 67/500, Loss: 0.3973, Accuracy: 81.13%
# Epoch 68/500, Loss: 0.3970, Accuracy: 82.08%
# Epoch 69/500, Loss: 0.3820, Accuracy: 83.53%
# Epoch 70/500, Loss: 0.3810, Accuracy: 81.73%
# Epoch 71/500, Loss: 0.3750, Accuracy: 82.20%
# Epoch 72/500, Loss: 0.3876, Accuracy: 81.43%
# Epoch 73/500, Loss: 0.3838, Accuracy: 81.78%
# Epoch 74/500, Loss: 0.3862, Accuracy: 82.29%
# Epoch 75/500, Loss: 0.3700, Accuracy: 84.05%
# Epoch 76/500, Loss: 0.3699, Accuracy: 82.93%
# Epoch 77/500, Loss: 0.3895, Accuracy: 81.82%
# Epoch 78/500, Loss: 0.3795, Accuracy: 82.12%
# Epoch 79/500, Loss: 0.3711, Accuracy: 83.06%
# Epoch 80/500, Loss: 0.3720, Accuracy: 83.06%
# Epoch 81/500, Loss: 0.3767, Accuracy: 82.33%
# Epoch 82/500, Loss: 0.3638, Accuracy: 83.45%
# Epoch 83/500, Loss: 0.3646, Accuracy: 83.19%
# Epoch 84/500, Loss: 0.3865, Accuracy: 82.98%
# Epoch 85/500, Loss: 0.3757, Accuracy: 82.29%
# Epoch 86/500, Loss: 0.3560, Accuracy: 83.88%
# Epoch 87/500, Loss: 0.3603, Accuracy: 83.79%
# Epoch 88/500, Loss: 0.3730, Accuracy: 83.10%
# Epoch 89/500, Loss: 0.3594, Accuracy: 83.10%
# Epoch 90/500, Loss: 0.3538, Accuracy: 83.66%
# Epoch 91/500, Loss: 0.3776, Accuracy: 83.45%
# Epoch 92/500, Loss: 0.3572, Accuracy: 84.13%
# Epoch 93/500, Loss: 0.3638, Accuracy: 84.48%
# Epoch 94/500, Loss: 0.3742, Accuracy: 82.03%
# Epoch 95/500, Loss: 0.3576, Accuracy: 84.09%
# Epoch 96/500, Loss: 0.3696, Accuracy: 84.01%
# Epoch 97/500, Loss: 0.3516, Accuracy: 82.55%
# Epoch 98/500, Loss: 0.3554, Accuracy: 83.15%
# Epoch 99/500, Loss: 0.3578, Accuracy: 84.05%
# Epoch 100/500, Loss: 0.3549, Accuracy: 83.79%
# Epoch 101/500, Loss: 0.3656, Accuracy: 83.75%
# Epoch 102/500, Loss: 0.3754, Accuracy: 82.68%
# Epoch 103/500, Loss: 0.3533, Accuracy: 84.43%
# Epoch 104/500, Loss: 0.3486, Accuracy: 84.69%
# Epoch 105/500, Loss: 0.3492, Accuracy: 84.31%
# Epoch 106/500, Loss: 0.3558, Accuracy: 83.53%
# Epoch 107/500, Loss: 0.3710, Accuracy: 82.29%
# Epoch 108/500, Loss: 0.3449, Accuracy: 84.91%
# Epoch 109/500, Loss: 0.3485, Accuracy: 83.75%
# Epoch 110/500, Loss: 0.3498, Accuracy: 83.79%
# Epoch 111/500, Loss: 0.3428, Accuracy: 84.26%
# Epoch 112/500, Loss: 0.3398, Accuracy: 84.52%
# Epoch 113/500, Loss: 0.3487, Accuracy: 84.35%
# Epoch 114/500, Loss: 0.3485, Accuracy: 84.43%
# Epoch 115/500, Loss: 0.3326, Accuracy: 84.78%
# Epoch 116/500, Loss: 0.3354, Accuracy: 84.31%
# Epoch 117/500, Loss: 0.3371, Accuracy: 84.86%
# Epoch 118/500, Loss: 0.3493, Accuracy: 84.05%
# Epoch 119/500, Loss: 0.3400, Accuracy: 84.82%
# Epoch 120/500, Loss: 0.3453, Accuracy: 84.61%
# Epoch 121/500, Loss: 0.3452, Accuracy: 84.73%
# Epoch 122/500, Loss: 0.3568, Accuracy: 83.88%
# Epoch 123/500, Loss: 0.3399, Accuracy: 84.73%
# Epoch 124/500, Loss: 0.3545, Accuracy: 84.56%
# Epoch 125/500, Loss: 0.3276, Accuracy: 84.52%
# Epoch 126/500, Loss: 0.3281, Accuracy: 84.39%
# Epoch 127/500, Loss: 0.3356, Accuracy: 84.91%
# Epoch 128/500, Loss: 0.3338, Accuracy: 84.78%
# Epoch 129/500, Loss: 0.3137, Accuracy: 86.19%
# Epoch 130/500, Loss: 0.3444, Accuracy: 84.18%
# Epoch 131/500, Loss: 0.3329, Accuracy: 85.03%
# Epoch 132/500, Loss: 0.3228, Accuracy: 84.99%
# Epoch 133/500, Loss: 0.3351, Accuracy: 85.59%
# Epoch 134/500, Loss: 0.3306, Accuracy: 85.59%
# Epoch 135/500, Loss: 0.3195, Accuracy: 85.72%
# Epoch 136/500, Loss: 0.3420, Accuracy: 83.96%
# Epoch 137/500, Loss: 0.3495, Accuracy: 84.18%
# Epoch 138/500, Loss: 0.3339, Accuracy: 85.33%
# Epoch 139/500, Loss: 0.3419, Accuracy: 84.82%
# Epoch 140/500, Loss: 0.3436, Accuracy: 84.48%
# Epoch 141/500, Loss: 0.3342, Accuracy: 84.78%
# Epoch 142/500, Loss: 0.3349, Accuracy: 85.59%
# Epoch 143/500, Loss: 0.3193, Accuracy: 85.93%
# Epoch 144/500, Loss: 0.3321, Accuracy: 84.82%
# Epoch 145/500, Loss: 0.3183, Accuracy: 86.19%
# Epoch 146/500, Loss: 0.3350, Accuracy: 84.78%
# Epoch 147/500, Loss: 0.3356, Accuracy: 85.21%
# Epoch 148/500, Loss: 0.3190, Accuracy: 86.19%
# Epoch 149/500, Loss: 0.3456, Accuracy: 83.92%
# Epoch 150/500, Loss: 0.3257, Accuracy: 85.38%
# Epoch 151/500, Loss: 0.3169, Accuracy: 87.05%
# Epoch 152/500, Loss: 0.3093, Accuracy: 86.19%
# Epoch 153/500, Loss: 0.3106, Accuracy: 86.58%
# Epoch 154/500, Loss: 0.3105, Accuracy: 86.15%
# Epoch 155/500, Loss: 0.3220, Accuracy: 86.84%
# Epoch 156/500, Loss: 0.3188, Accuracy: 85.89%
# Epoch 157/500, Loss: 0.3149, Accuracy: 86.19%
# Epoch 158/500, Loss: 0.3114, Accuracy: 87.14%
# Epoch 159/500, Loss: 0.3107, Accuracy: 85.93%
# Epoch 160/500, Loss: 0.3079, Accuracy: 86.36%
# Epoch 161/500, Loss: 0.3466, Accuracy: 85.38%
# Epoch 162/500, Loss: 0.3061, Accuracy: 86.32%
# Epoch 163/500, Loss: 0.3109, Accuracy: 86.54%
# Epoch 164/500, Loss: 0.3291, Accuracy: 85.72%
# Epoch 165/500, Loss: 0.3241, Accuracy: 85.63%
# Epoch 166/500, Loss: 0.3115, Accuracy: 86.96%
# Epoch 167/500, Loss: 0.3122, Accuracy: 85.98%
# Epoch 168/500, Loss: 0.3054, Accuracy: 86.75%
# Epoch 169/500, Loss: 0.3146, Accuracy: 86.19%
# Epoch 170/500, Loss: 0.3062, Accuracy: 85.76%
# Epoch 171/500, Loss: 0.3181, Accuracy: 86.15%
# Epoch 172/500, Loss: 0.3101, Accuracy: 86.15%
# Epoch 173/500, Loss: 0.3249, Accuracy: 85.12%
# Epoch 174/500, Loss: 0.3122, Accuracy: 86.49%
# Epoch 175/500, Loss: 0.3017, Accuracy: 86.79%
# Epoch 176/500, Loss: 0.3194, Accuracy: 85.89%
# Epoch 177/500, Loss: 0.3050, Accuracy: 86.32%
# Epoch 178/500, Loss: 0.3079, Accuracy: 86.71%
# Epoch 179/500, Loss: 0.2986, Accuracy: 87.31%
# Epoch 180/500, Loss: 0.2918, Accuracy: 87.31%
# Epoch 181/500, Loss: 0.3074, Accuracy: 86.84%
# Epoch 182/500, Loss: 0.3145, Accuracy: 86.58%
# Epoch 183/500, Loss: 0.3088, Accuracy: 85.93%
# Epoch 184/500, Loss: 0.2948, Accuracy: 87.22%
# Epoch 185/500, Loss: 0.2934, Accuracy: 87.18%
# Epoch 186/500, Loss: 0.2943, Accuracy: 86.71%
# Epoch 187/500, Loss: 0.3086, Accuracy: 86.28%
# Epoch 188/500, Loss: 0.2987, Accuracy: 86.79%
# Epoch 189/500, Loss: 0.3049, Accuracy: 86.88%
# Epoch 190/500, Loss: 0.3033, Accuracy: 86.45%
# Epoch 191/500, Loss: 0.3042, Accuracy: 86.84%
# Epoch 192/500, Loss: 0.2920, Accuracy: 87.22%
# Epoch 193/500, Loss: 0.2814, Accuracy: 87.91%
# Epoch 194/500, Loss: 0.3094, Accuracy: 85.59%
# Epoch 195/500, Loss: 0.2951, Accuracy: 87.39%
# Epoch 196/500, Loss: 0.3007, Accuracy: 86.75%
# Epoch 197/500, Loss: 0.2997, Accuracy: 87.01%
# Epoch 198/500, Loss: 0.2919, Accuracy: 87.78%
# Epoch 199/500, Loss: 0.2975, Accuracy: 87.14%
# Epoch 200/500, Loss: 0.2955, Accuracy: 87.44%
# Epoch 201/500, Loss: 0.3101, Accuracy: 86.75%
# Epoch 202/500, Loss: 0.2947, Accuracy: 87.26%
# Epoch 203/500, Loss: 0.2926, Accuracy: 87.05%
# Epoch 204/500, Loss: 0.3189, Accuracy: 85.72%
# Epoch 205/500, Loss: 0.3079, Accuracy: 87.09%
# Epoch 206/500, Loss: 0.2834, Accuracy: 88.12%
# Epoch 207/500, Loss: 0.3030, Accuracy: 87.05%
# Epoch 208/500, Loss: 0.3110, Accuracy: 87.05%
# Epoch 209/500, Loss: 0.2910, Accuracy: 87.82%
# Epoch 210/500, Loss: 0.2933, Accuracy: 86.58%
# Epoch 211/500, Loss: 0.3040, Accuracy: 86.02%
# Epoch 212/500, Loss: 0.3031, Accuracy: 86.96%
# Epoch 213/500, Loss: 0.3008, Accuracy: 87.86%
# Epoch 214/500, Loss: 0.3059, Accuracy: 87.22%
# Epoch 215/500, Loss: 0.3030, Accuracy: 86.71%
# Epoch 216/500, Loss: 0.2999, Accuracy: 86.41%
# Epoch 217/500, Loss: 0.2920, Accuracy: 87.35%
# Epoch 218/500, Loss: 0.3067, Accuracy: 87.44%
# Epoch 219/500, Loss: 0.2934, Accuracy: 87.82%
# Epoch 220/500, Loss: 0.2851, Accuracy: 88.16%
# Epoch 221/500, Loss: 0.3013, Accuracy: 86.92%
# Epoch 222/500, Loss: 0.2817, Accuracy: 88.29%
# Epoch 223/500, Loss: 0.2866, Accuracy: 87.48%
# Epoch 224/500, Loss: 0.3028, Accuracy: 86.36%
# Epoch 225/500, Loss: 0.2958, Accuracy: 87.52%
# Epoch 226/500, Loss: 0.2894, Accuracy: 87.48%
# Epoch 227/500, Loss: 0.3008, Accuracy: 86.96%
# Epoch 228/500, Loss: 0.3103, Accuracy: 86.32%
# Epoch 229/500, Loss: 0.2805, Accuracy: 88.72%
# Epoch 230/500, Loss: 0.2952, Accuracy: 87.39%
# Epoch 231/500, Loss: 0.2879, Accuracy: 87.61%
# Epoch 232/500, Loss: 0.2948, Accuracy: 86.92%
# Epoch 233/500, Loss: 0.2905, Accuracy: 87.31%
# Epoch 234/500, Loss: 0.2858, Accuracy: 88.08%
# Epoch 235/500, Loss: 0.2765, Accuracy: 88.55%
# Epoch 236/500, Loss: 0.2825, Accuracy: 88.46%
# Epoch 237/500, Loss: 0.2952, Accuracy: 87.09%
# Epoch 238/500, Loss: 0.2906, Accuracy: 87.91%
# Epoch 239/500, Loss: 0.2920, Accuracy: 87.99%
# Epoch 240/500, Loss: 0.2844, Accuracy: 87.86%
# Epoch 241/500, Loss: 0.2879, Accuracy: 87.74%
# Epoch 242/500, Loss: 0.2823, Accuracy: 87.65%
# Epoch 243/500, Loss: 0.2945, Accuracy: 87.44%
# Epoch 244/500, Loss: 0.3071, Accuracy: 86.96%
# Epoch 245/500, Loss: 0.2791, Accuracy: 88.51%
# Epoch 246/500, Loss: 0.2840, Accuracy: 87.31%
# Epoch 247/500, Loss: 0.2936, Accuracy: 87.82%
# Epoch 248/500, Loss: 0.2809, Accuracy: 88.68%
# Epoch 249/500, Loss: 0.2959, Accuracy: 87.44%
# Epoch 250/500, Loss: 0.3004, Accuracy: 87.48%
# Epoch 251/500, Loss: 0.2944, Accuracy: 87.52%
# Epoch 252/500, Loss: 0.2925, Accuracy: 86.88%
# Epoch 253/500, Loss: 0.2909, Accuracy: 87.74%
# Epoch 254/500, Loss: 0.2798, Accuracy: 88.16%
# Epoch 255/500, Loss: 0.2938, Accuracy: 87.26%
# Epoch 256/500, Loss: 0.2949, Accuracy: 86.41%
# Epoch 257/500, Loss: 0.2826, Accuracy: 87.69%
# Epoch 258/500, Loss: 0.2724, Accuracy: 88.34%
# Epoch 259/500, Loss: 0.2713, Accuracy: 88.46%
# Epoch 260/500, Loss: 0.2848, Accuracy: 88.04%
# Epoch 261/500, Loss: 0.2791, Accuracy: 87.74%
# Epoch 262/500, Loss: 0.2862, Accuracy: 87.65%
# Epoch 263/500, Loss: 0.2883, Accuracy: 86.88%
# Epoch 264/500, Loss: 0.2789, Accuracy: 88.34%
# Epoch 265/500, Loss: 0.2901, Accuracy: 86.88%
# Epoch 266/500, Loss: 0.2706, Accuracy: 89.37%
# Epoch 267/500, Loss: 0.2670, Accuracy: 88.81%
# Epoch 268/500, Loss: 0.2479, Accuracy: 90.18%
# Epoch 269/500, Loss: 0.3024, Accuracy: 86.58%
# Epoch 270/500, Loss: 0.2606, Accuracy: 88.38%
# Epoch 271/500, Loss: 0.2840, Accuracy: 87.65%
# Epoch 272/500, Loss: 0.2779, Accuracy: 87.39%
# Epoch 273/500, Loss: 0.2799, Accuracy: 88.21%
# Epoch 274/500, Loss: 0.2976, Accuracy: 87.52%
# Epoch 275/500, Loss: 0.2826, Accuracy: 87.82%
# Epoch 276/500, Loss: 0.2904, Accuracy: 87.52%
# Epoch 277/500, Loss: 0.2669, Accuracy: 88.42%
# Epoch 278/500, Loss: 0.2774, Accuracy: 88.81%
# Epoch 279/500, Loss: 0.2649, Accuracy: 88.59%
# Epoch 280/500, Loss: 0.2881, Accuracy: 87.09%
# Epoch 281/500, Loss: 0.2658, Accuracy: 87.91%
# Epoch 282/500, Loss: 0.2719, Accuracy: 89.07%
# Epoch 283/500, Loss: 0.2688, Accuracy: 87.99%
# Epoch 284/500, Loss: 0.2733, Accuracy: 88.64%
# Epoch 285/500, Loss: 0.2710, Accuracy: 88.81%
# Epoch 286/500, Loss: 0.2789, Accuracy: 87.99%
# Epoch 287/500, Loss: 0.2745, Accuracy: 88.72%
# Epoch 288/500, Loss: 0.2915, Accuracy: 88.12%
# Epoch 289/500, Loss: 0.2827, Accuracy: 87.99%
# Epoch 290/500, Loss: 0.2769, Accuracy: 88.21%
# Epoch 291/500, Loss: 0.2703, Accuracy: 88.55%
# Epoch 292/500, Loss: 0.2753, Accuracy: 88.38%
# Epoch 293/500, Loss: 0.2694, Accuracy: 88.64%
# Epoch 294/500, Loss: 0.2501, Accuracy: 89.71%
# Epoch 295/500, Loss: 0.2654, Accuracy: 88.98%
# Epoch 296/500, Loss: 0.2842, Accuracy: 87.52%
# Epoch 297/500, Loss: 0.2768, Accuracy: 87.31%
# Epoch 298/500, Loss: 0.2721, Accuracy: 88.59%
# Epoch 299/500, Loss: 0.2640, Accuracy: 89.02%
# Epoch 300/500, Loss: 0.2664, Accuracy: 88.04%
# Epoch 301/500, Loss: 0.2770, Accuracy: 87.74%
# Epoch 302/500, Loss: 0.2603, Accuracy: 89.28%
# Epoch 303/500, Loss: 0.2795, Accuracy: 87.78%
# Epoch 304/500, Loss: 0.2735, Accuracy: 88.21%
# Epoch 305/500, Loss: 0.2709, Accuracy: 88.21%
# Epoch 306/500, Loss: 0.2752, Accuracy: 88.81%
# Epoch 307/500, Loss: 0.2673, Accuracy: 88.34%
# Epoch 308/500, Loss: 0.2480, Accuracy: 89.62%
# Epoch 309/500, Loss: 0.2773, Accuracy: 88.16%
# Epoch 310/500, Loss: 0.2564, Accuracy: 88.55%
# Epoch 311/500, Loss: 0.2796, Accuracy: 88.12%
# Epoch 312/500, Loss: 0.2713, Accuracy: 88.16%
# Epoch 313/500, Loss: 0.2646, Accuracy: 89.71%
# Epoch 314/500, Loss: 0.2444, Accuracy: 89.11%
# Epoch 315/500, Loss: 0.2656, Accuracy: 89.37%
# Epoch 316/500, Loss: 0.2797, Accuracy: 87.86%
# Epoch 317/500, Loss: 0.2714, Accuracy: 88.42%
# Epoch 318/500, Loss: 0.2605, Accuracy: 88.98%
# Epoch 319/500, Loss: 0.2654, Accuracy: 88.51%
# Epoch 320/500, Loss: 0.2697, Accuracy: 89.11%
# Epoch 321/500, Loss: 0.2587, Accuracy: 89.24%
# Epoch 322/500, Loss: 0.2818, Accuracy: 87.86%
# Epoch 323/500, Loss: 0.2604, Accuracy: 89.19%
# Epoch 324/500, Loss: 0.2724, Accuracy: 88.29%
# Epoch 325/500, Loss: 0.2561, Accuracy: 89.49%
# Epoch 326/500, Loss: 0.2478, Accuracy: 89.79%
# Epoch 327/500, Loss: 0.2601, Accuracy: 88.94%
# Epoch 328/500, Loss: 0.2791, Accuracy: 88.68%
# Epoch 329/500, Loss: 0.2482, Accuracy: 90.27%
# Epoch 330/500, Loss: 0.2763, Accuracy: 88.42%
# Epoch 331/500, Loss: 0.2558, Accuracy: 89.54%
# Epoch 332/500, Loss: 0.2561, Accuracy: 88.72%
# Epoch 333/500, Loss: 0.2937, Accuracy: 87.39%
# Epoch 334/500, Loss: 0.2667, Accuracy: 89.15%
# Epoch 335/500, Loss: 0.2638, Accuracy: 89.02%
# Epoch 336/500, Loss: 0.2717, Accuracy: 88.25%
# Epoch 337/500, Loss: 0.2653, Accuracy: 88.29%
# Epoch 338/500, Loss: 0.2701, Accuracy: 88.34%
# Epoch 339/500, Loss: 0.2760, Accuracy: 87.78%
# Epoch 340/500, Loss: 0.2641, Accuracy: 89.32%
# Epoch 341/500, Loss: 0.2530, Accuracy: 90.35%
# Epoch 342/500, Loss: 0.2752, Accuracy: 87.65%
# Epoch 343/500, Loss: 0.2722, Accuracy: 88.51%
# Epoch 344/500, Loss: 0.2710, Accuracy: 88.42%
# Epoch 345/500, Loss: 0.2747, Accuracy: 88.68%
# Epoch 346/500, Loss: 0.2583, Accuracy: 88.89%
# Epoch 347/500, Loss: 0.2558, Accuracy: 89.07%
# Epoch 348/500, Loss: 0.2517, Accuracy: 89.41%
# Epoch 349/500, Loss: 0.2676, Accuracy: 88.85%
# Epoch 350/500, Loss: 0.2509, Accuracy: 89.07%
# Epoch 351/500, Loss: 0.2686, Accuracy: 89.02%
# Epoch 352/500, Loss: 0.2618, Accuracy: 88.08%
# Epoch 353/500, Loss: 0.2486, Accuracy: 89.97%
# Epoch 354/500, Loss: 0.2662, Accuracy: 88.81%
# Epoch 355/500, Loss: 0.2841, Accuracy: 88.08%
# Epoch 356/500, Loss: 0.2517, Accuracy: 89.49%
# Epoch 357/500, Loss: 0.2342, Accuracy: 89.92%
# Epoch 358/500, Loss: 0.2498, Accuracy: 89.11%
# Epoch 359/500, Loss: 0.2609, Accuracy: 88.89%
# Epoch 360/500, Loss: 0.2663, Accuracy: 88.21%
# Epoch 361/500, Loss: 0.2466, Accuracy: 89.62%
# Epoch 362/500, Loss: 0.2695, Accuracy: 88.08%
# Epoch 363/500, Loss: 0.2545, Accuracy: 89.19%
# Epoch 364/500, Loss: 0.2593, Accuracy: 88.59%
# Epoch 365/500, Loss: 0.2534, Accuracy: 89.45%
# Epoch 366/500, Loss: 0.2543, Accuracy: 89.02%
# Epoch 367/500, Loss: 0.2545, Accuracy: 89.28%
# Epoch 368/500, Loss: 0.2641, Accuracy: 89.15%
# Epoch 369/500, Loss: 0.2621, Accuracy: 88.81%
# Epoch 370/500, Loss: 0.2505, Accuracy: 89.49%
# Epoch 371/500, Loss: 0.2566, Accuracy: 88.64%
# Epoch 372/500, Loss: 0.2682, Accuracy: 88.64%
# Epoch 373/500, Loss: 0.2614, Accuracy: 89.24%
# Epoch 374/500, Loss: 0.2416, Accuracy: 89.37%
# Epoch 375/500, Loss: 0.2634, Accuracy: 88.42%
# Epoch 376/500, Loss: 0.2782, Accuracy: 87.99%
# Epoch 377/500, Loss: 0.2570, Accuracy: 88.46%
# Epoch 378/500, Loss: 0.2634, Accuracy: 89.58%
# Epoch 379/500, Loss: 0.2439, Accuracy: 90.14%
# Epoch 380/500, Loss: 0.2591, Accuracy: 89.07%
# Epoch 381/500, Loss: 0.2626, Accuracy: 89.37%
# Epoch 382/500, Loss: 0.2645, Accuracy: 88.12%
# Epoch 383/500, Loss: 0.2668, Accuracy: 89.11%
# Epoch 384/500, Loss: 0.2615, Accuracy: 88.64%
# Epoch 385/500, Loss: 0.2548, Accuracy: 88.98%
# Epoch 386/500, Loss: 0.2508, Accuracy: 89.19%
# Epoch 387/500, Loss: 0.2533, Accuracy: 89.24%
# Epoch 388/500, Loss: 0.2450, Accuracy: 89.62%
# Epoch 389/500, Loss: 0.2688, Accuracy: 88.81%
# Epoch 390/500, Loss: 0.2507, Accuracy: 89.15%
# Epoch 391/500, Loss: 0.2585, Accuracy: 89.19%
# Epoch 392/500, Loss: 0.2584, Accuracy: 89.15%
# Epoch 393/500, Loss: 0.2656, Accuracy: 88.42%
# Epoch 394/500, Loss: 0.2564, Accuracy: 89.37%
# Epoch 395/500, Loss: 0.2621, Accuracy: 88.85%
# Epoch 396/500, Loss: 0.2591, Accuracy: 89.49%
# Epoch 397/500, Loss: 0.2655, Accuracy: 88.38%
# Epoch 398/500, Loss: 0.2476, Accuracy: 89.07%
# Epoch 399/500, Loss: 0.2471, Accuracy: 90.22%
# Epoch 400/500, Loss: 0.2399, Accuracy: 89.84%
# Epoch 401/500, Loss: 0.2536, Accuracy: 89.24%
# Epoch 402/500, Loss: 0.2514, Accuracy: 89.11%
# Epoch 403/500, Loss: 0.2421, Accuracy: 89.37%
# Epoch 404/500, Loss: 0.2367, Accuracy: 90.18%
# Epoch 405/500, Loss: 0.2513, Accuracy: 89.37%
# Epoch 406/500, Loss: 0.2532, Accuracy: 89.24%
# Epoch 407/500, Loss: 0.2538, Accuracy: 88.85%
# Epoch 408/500, Loss: 0.2295, Accuracy: 90.87%
# Epoch 409/500, Loss: 0.2687, Accuracy: 88.42%
# Epoch 410/500, Loss: 0.2480, Accuracy: 89.15%
# Epoch 411/500, Loss: 0.2499, Accuracy: 89.71%
# Epoch 412/500, Loss: 0.2453, Accuracy: 89.88%
# Epoch 413/500, Loss: 0.2585, Accuracy: 89.37%
# Epoch 414/500, Loss: 0.2463, Accuracy: 89.49%
# Epoch 415/500, Loss: 0.2375, Accuracy: 90.22%
# Epoch 416/500, Loss: 0.2384, Accuracy: 89.92%
# Epoch 417/500, Loss: 0.2409, Accuracy: 89.75%
# Epoch 418/500, Loss: 0.2480, Accuracy: 90.05%
# Epoch 419/500, Loss: 0.2347, Accuracy: 90.74%
# Epoch 420/500, Loss: 0.2426, Accuracy: 89.67%
# Epoch 421/500, Loss: 0.2520, Accuracy: 89.58%
# Epoch 422/500, Loss: 0.2540, Accuracy: 89.02%
# Epoch 423/500, Loss: 0.2444, Accuracy: 89.62%
# Epoch 424/500, Loss: 0.2368, Accuracy: 89.84%
# Epoch 425/500, Loss: 0.2562, Accuracy: 89.49%
# Epoch 426/500, Loss: 0.2526, Accuracy: 89.49%
# Epoch 427/500, Loss: 0.2384, Accuracy: 89.41%
# Epoch 428/500, Loss: 0.2420, Accuracy: 90.82%
# Epoch 429/500, Loss: 0.2568, Accuracy: 89.28%
# Epoch 430/500, Loss: 0.2395, Accuracy: 90.01%
# Epoch 431/500, Loss: 0.2436, Accuracy: 90.48%
# Epoch 432/500, Loss: 0.2299, Accuracy: 90.35%
# Epoch 433/500, Loss: 0.2488, Accuracy: 89.71%
# Epoch 434/500, Loss: 0.2441, Accuracy: 89.58%
# Epoch 435/500, Loss: 0.2550, Accuracy: 89.58%
# Epoch 436/500, Loss: 0.2386, Accuracy: 90.18%
# Epoch 437/500, Loss: 0.2545, Accuracy: 89.62%
# Epoch 438/500, Loss: 0.2425, Accuracy: 89.97%
# Epoch 439/500, Loss: 0.2316, Accuracy: 90.27%
# Epoch 440/500, Loss: 0.2533, Accuracy: 89.11%
# Epoch 441/500, Loss: 0.2525, Accuracy: 89.11%
# Epoch 442/500, Loss: 0.2594, Accuracy: 88.77%
# Epoch 443/500, Loss: 0.2478, Accuracy: 89.67%
# Epoch 444/500, Loss: 0.2555, Accuracy: 89.62%
# Epoch 445/500, Loss: 0.2598, Accuracy: 89.15%
# Epoch 446/500, Loss: 0.2607, Accuracy: 89.07%
# Epoch 447/500, Loss: 0.2358, Accuracy: 89.79%
# Epoch 448/500, Loss: 0.2423, Accuracy: 89.92%
# Epoch 449/500, Loss: 0.2382, Accuracy: 89.97%
# Epoch 450/500, Loss: 0.2576, Accuracy: 88.72%
# Epoch 451/500, Loss: 0.2422, Accuracy: 89.71%
# Epoch 452/500, Loss: 0.2212, Accuracy: 90.52%
# Epoch 453/500, Loss: 0.2350, Accuracy: 90.22%
# Epoch 454/500, Loss: 0.2484, Accuracy: 89.32%
# Epoch 455/500, Loss: 0.2416, Accuracy: 89.97%
# Epoch 456/500, Loss: 0.2559, Accuracy: 88.77%
# Epoch 457/500, Loss: 0.2397, Accuracy: 90.05%
# Epoch 458/500, Loss: 0.2476, Accuracy: 89.28%
# Epoch 459/500, Loss: 0.2493, Accuracy: 89.75%
# Epoch 460/500, Loss: 0.2481, Accuracy: 89.84%
# Epoch 461/500, Loss: 0.2489, Accuracy: 89.79%
# Epoch 462/500, Loss: 0.2668, Accuracy: 88.68%
# Epoch 463/500, Loss: 0.2627, Accuracy: 88.77%
# Epoch 464/500, Loss: 0.2392, Accuracy: 89.54%
# Epoch 465/500, Loss: 0.2326, Accuracy: 90.65%
# Epoch 466/500, Loss: 0.2538, Accuracy: 89.28%
# Epoch 467/500, Loss: 0.2538, Accuracy: 89.67%
# Epoch 468/500, Loss: 0.2546, Accuracy: 89.45%
# Epoch 469/500, Loss: 0.2467, Accuracy: 90.27%
# Epoch 470/500, Loss: 0.2325, Accuracy: 89.97%
# Epoch 471/500, Loss: 0.2407, Accuracy: 89.67%
# Epoch 472/500, Loss: 0.2426, Accuracy: 89.92%
# Epoch 473/500, Loss: 0.2299, Accuracy: 90.99%
# Epoch 474/500, Loss: 0.2363, Accuracy: 89.84%
# Epoch 475/500, Loss: 0.2453, Accuracy: 89.84%
# Epoch 476/500, Loss: 0.2455, Accuracy: 89.49%
# Epoch 477/500, Loss: 0.2450, Accuracy: 89.71%
# Epoch 478/500, Loss: 0.2441, Accuracy: 90.39%
# Epoch 479/500, Loss: 0.2418, Accuracy: 90.01%
# Epoch 480/500, Loss: 0.2503, Accuracy: 89.71%
# Epoch 481/500, Loss: 0.2671, Accuracy: 89.62%
# Epoch 482/500, Loss: 0.2672, Accuracy: 89.15%
# Epoch 483/500, Loss: 0.2420, Accuracy: 90.39%
# Epoch 484/500, Loss: 0.2427, Accuracy: 90.18%
# Epoch 485/500, Loss: 0.2342, Accuracy: 90.31%
# Epoch 486/500, Loss: 0.2464, Accuracy: 89.32%
# Epoch 487/500, Loss: 0.2368, Accuracy: 90.69%
# Epoch 488/500, Loss: 0.2383, Accuracy: 90.18%
# Epoch 489/500, Loss: 0.2492, Accuracy: 90.22%
# Epoch 490/500, Loss: 0.2490, Accuracy: 89.28%
# Epoch 491/500, Loss: 0.2278, Accuracy: 90.18%
# Epoch 492/500, Loss: 0.2285, Accuracy: 90.57%
# Epoch 493/500, Loss: 0.2353, Accuracy: 90.44%
# Epoch 494/500, Loss: 0.2297, Accuracy: 90.31%
# Epoch 495/500, Loss: 0.2439, Accuracy: 90.01%
# Epoch 496/500, Loss: 0.2236, Accuracy: 90.44%
# Epoch 497/500, Loss: 0.2385, Accuracy: 90.61%
# Epoch 498/500, Loss: 0.2430, Accuracy: 90.18%
# Epoch 499/500, Loss: 0.2287, Accuracy: 90.69%
# Epoch 500/500, Loss: 0.2288, Accuracy: 90.14%
# Average Loss: 0.22877265634989657
# Highest Train Accuracy: 0.9099485420240138

# %% [markdown]
# ##Evaluating Model

# %%
classes_list = ['Left', 'Right']
eval_model = EvalModel(trained_eegnet_model)
test_accuracy = eval_model.test_model(test_dataset)
eval_model.plot_confusion_matrix(test_dataset, classes_list)
# Out:
# /------------------------------/
# Test Accuracy: 89.23%
# /------------------------------/

# %%
#f1스코어 알아내기 위한 코드 삽입
from sklearn.metrics import f1_score, classification_report
from torch.utils.data import DataLoader
import torch
import numpy as np

def get_predictions(model, dataset, batch_size=64):
    model.eval()
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    y_true = []
    y_pred = []

    with torch.no_grad():
        for X, y in loader:
            X = X.to(device)
            y = y.to(device)

            outputs = model(X)
            preds = torch.argmax(outputs, dim=1)

            y_true.extend(y.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    return np.array(y_true), np.array(y_pred)


y_true, y_pred = get_predictions(trained_eegnet_model, test_dataset)

macro_f1 = f1_score(y_true, y_pred, average='macro')
weighted_f1 = f1_score(y_true, y_pred, average='weighted')

print("Macro F1:", macro_f1)
print("Weighted F1:", weighted_f1)

print(classification_report(y_true, y_pred, target_names=classes_list))
# Out:
# Macro F1: 0.8923076923076924
# Weighted F1: 0.8923076923076924
#               precision    recall  f1-score   support
#
#         Left       0.89      0.89      0.89       130
#        Right       0.89      0.89      0.89       130
#
#     accuracy                           0.89       260
#    macro avg       0.89      0.89      0.89       260
# weighted avg       0.89      0.89      0.89       260

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

print("Unique y_true:", np.unique(y_true, return_counts=True))
print("Unique y_pred:", np.unique(y_pred, return_counts=True))

cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# Unique y_true: (array([0, 1]), array([130, 130]))
# Unique y_pred: (array([0, 1]), array([130, 130]))
# [[116  14]
#  [ 14 116]]

# %%
print("Train data shape:", train_dataset.tensors[0].shape)
print("Train label shape:", train_dataset.tensors[1].shape)

print("Test data shape:", test_dataset.tensors[0].shape)
print("Test label shape:", test_dataset.tensors[1].shape)
# Out:
# Train data shape: torch.Size([2332, 1, 22, 1001])
# Train label shape: torch.Size([2332])
# Test data shape: torch.Size([260, 1, 22, 1001])
# Test label shape: torch.Size([260])
