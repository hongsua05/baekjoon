# %% [markdown]
# <a href="https://colab.research.google.com/github/hongsua05/baekjoon/blob/main/EEGNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motor Imagery Task Classification

# %% [markdown]
# #Extracting Data

# %% [markdown]
# ##Downloading BCI Competition IV 2a Dataset

# %%
# !wget https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# Out:
# --2026-05-18 06:09:56--  https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# Resolving www.bbci.de (www.bbci.de)... 141.23.71.83
# Connecting to www.bbci.de (www.bbci.de)|141.23.71.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 439968864 (420M) [application/zip]
# Saving to: ‘BCICIV_2a_gdf.zip’
#
# BCICIV_2a_gdf.zip   100%[===================>] 419.59M   185MB/s    in 2.3s
#
# 2026-05-18 06:09:58 (185 MB/s) - ‘BCICIV_2a_gdf.zip’ saved [439968864/439968864]

# %%
# !mkdir -p /content/cleaned_data/

# %%
# %%capture
# !unzip /content/BCICIV_2a_gdf.zip -d raw_data

# %% [markdown]
# #Installing Packages

# %%
# %%capture
# !pip install mne

# %%
# %%capture
# !pip install torch-summary

# %% [markdown]
# #Libraries Used

# %%
import os
import mne
import math
import copy
import gdown
import random
import scipy.io
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Building Dataset

# %%
# !mkdir -p /content/cleaned_data/first_session
# !mkdir -p /content/cleaned_data/second_session

# %% [markdown]
# ##First Session

# %%
raw_data_folder = '/content/raw_data/'
cleaned_data_folder = '/content/cleaned_data/first_session/'
files = os.listdir(raw_data_folder)

# Selecting files with suffix 'T.gdf'
filtered_files = [file for file in files if file.endswith('T.gdf')]

raw_list = []

# Iterating through filtered files
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Reading raw data
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
    # Droping EOG channels
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # High Pass Filtering 4-40 Hz
    raw.filter(l_freq=4, h_freq=40, method='iir')

    # Notch filter for Removal of Line Voltage
    raw.notch_filter(freqs=50)

    # Saving the modified raw data to a file with .fif suffix
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)
    # Appending data to the list
    raw_list.append(raw)

final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'First_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting GDF parameters from /content/raw_data/A09T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Reading 0 ... 673327  =      0.000 ...  2693.308 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A09T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A09T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A09T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A05T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686119  =      0.000 ...  2744.476 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A05T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A05T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A05T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A07T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 681070  =      0.000 ...  2724.280 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A07T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A07T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A07T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A04T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 600914  =      0.000 ...  2403.656 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A04T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A04T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A04T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A06T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 678979  =      0.000 ...  2715.916 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A06T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A06T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A06T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A03T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 660529  =      0.000 ...  2642.116 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A03T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A03T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A03T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A02T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 677168  =      0.000 ...  2708.672 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A02T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A02T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A02T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A01T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A01T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A01T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A01T.fif
# [done]
# Extracting GDF parameters from /content/raw_data/A08T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 675269  =      0.000 ...  2701.076 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Writing /content/cleaned_data/first_session/A08T.fif
# /tmp/ipykernel_4923/468050219.py:27: RuntimeWarning: This filename (/content/cleaned_data/first_session/A08T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/A08T.fif
# [done]
# Writing /content/cleaned_data/first_session/First_Session_Subjects.fif
# /tmp/ipykernel_4923/468050219.py:33: RuntimeWarning: This filename (/content/cleaned_data/first_session/First_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/first_session/First_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/first_session/First_Session_Subjects.fif')]

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '769': 7 Cue onset **Left** (class 1) : 0
# '770': 8 Cue onset **Right** (class 2) : 1
# '771': 9 Cue onset **Foot** (class 3) : 2
# '772': 10 Cue onset **Tongue** (class 4): 3

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('769'), np.str_('770'), np.str_('771'), np.str_('772')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('769'): 7,
#  np.str_('770'): 8,
#  np.str_('771'): 9,
#  np.str_('772'): 10}

# %% [markdown]
# **Time choice:**
# [0.s, 4s] Post Cue on set:  [2s, 6s]

# %%
epochs = mne.Epochs(final_raw, events[0], event_id=[7, 8, 9, 10], tmin=0, tmax=4, reject=None, baseline=None, preload=True)
first_session_data = epochs.get_data(copy=True)
first_session_labels = epochs.events[:,-1]
# Out:
# Not setting metadata
# 2592 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2592 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
print("First_session_dataset shape:",first_session_data.shape)
# Out:
# First_session_dataset shape: (2592, 22, 1001)

# %% [markdown]
# ##Second Session

# %% [markdown]
# ###Extracting Labels for datas with "E.gdf" prefix

# %%
# Replace this with your actual shareable link
shareable_link = 'https://drive.google.com/file/d/11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo/view?usp=drive_link'

# Extract file ID from the shareable link
file_id = shareable_link.split('/d/')[1].split('/view')[0]

# Create the direct download link
download_url = f'https://drive.google.com/uc?id={file_id}&export=download'

# Specify the output file path
output_file = 'true_labels.zip'

# Download the file
gdown.download(download_url, output_file, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo&export=download
# To: /content/true_labels.zip
# 100%|██████████| 7.20k/7.20k [00:00<00:00, 17.1MB/s]
# 'true_labels.zip'

# %%
# %%capture
# !unzip /content/true_labels.zip -d second_session_labels

# %% [markdown]
# ###Extracting datas of second session

# %%
raw_data_folder = '/content/raw_data/'
cleaned_data_folder = '/content/cleaned_data/second_session/'
mat_folder = '/content/second_session_labels/'

# Selecting files with suffix 'E.mat'
mat_files = os.listdir(mat_folder)
filtered_math_labels = [file for file in mat_files if file.endswith('E.mat')]

# Selecting files with suffix 'E.gdf'
files = os.listdir(raw_data_folder)
filtered_files = [file for file in files if file.endswith('E.gdf')]

raw_list = []
second_session_labels = np.array([])
# Iterating through filtered files
for file in filtered_files:
    file_path = os.path.join(raw_data_folder, file)

    # Reading raw data
    raw = mne.io.read_raw_gdf(file_path, eog=['EOG-left', 'EOG-central', 'EOG-right'], preload=True)
    # Droping EOG channels
    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # High Pass Filtering 4-40 Hz
    raw.filter(l_freq=4, h_freq=40, method='iir')

    # Saving the modified raw data to a file with .fif suffix
    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')
    raw.save(new_file_path, overwrite=True)
    # Appending data to t he list
    raw_list.append(raw)

    # Mat files for the labels
    mat_file_name = file.replace('.gdf', '.mat')
    mat_file_path = os.path.join(mat_folder, mat_file_name)
    print(f"data:{file}, label:{mat_file_name}")

    if os.path.exists(mat_file_path):
        mat_data = scipy.io.loadmat(mat_file_path)
        class_labels = mat_data.get('classlabel', [])

        # Check if 'classlabel' key exists and is not empty
        if class_labels.size > 0:
             # Convert to a NumPy array and flatten
            class_labels_array = np.array(class_labels, dtype=int).flatten()
            # Concatenate with the existing test_labels array
            second_session_labels = np.concatenate((second_session_labels, class_labels_array))
        else:
            print(f"Warning: 'classlabel' not found or empty in {mat_file_name}.")
    else:
        print(f"Warning: {mat_file_name} not found.")

final_raw = mne.concatenate_raws(raw_list)
new_file_path = os.path.join(cleaned_data_folder, 'Second_Session_Subjects.fif')
final_raw.save(new_file_path, overwrite=True)
# Out:
# Extracting GDF parameters from /content/raw_data/A06E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 666372  =      0.000 ...  2665.488 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A06E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A06E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A06E.fif
# [done]
# data:A06E.gdf, label:A06E.mat
# Extracting GDF parameters from /content/raw_data/A08E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 687791  =      0.000 ...  2751.164 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A08E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A08E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A08E.fif
# [done]
# data:A08E.gdf, label:A08E.mat
# Extracting GDF parameters from /content/raw_data/A01E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686999  =      0.000 ...  2747.996 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A01E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A01E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A01E.fif
# [done]
# data:A01E.gdf, label:A01E.mat
# Extracting GDF parameters from /content/raw_data/A09E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 675097  =      0.000 ...  2700.388 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A09E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A09E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A09E.fif
# [done]
# data:A09E.gdf, label:A09E.mat
# Extracting GDF parameters from /content/raw_data/A05E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 679862  =      0.000 ...  2719.448 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A05E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A05E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A05E.fif
# [done]
# data:A05E.gdf, label:A05E.mat
# Extracting GDF parameters from /content/raw_data/A02E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 662665  =      0.000 ...  2650.660 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A02E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A02E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A02E.fif
# [done]
# data:A02E.gdf, label:A02E.mat
# Extracting GDF parameters from /content/raw_data/A04E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 660046  =      0.000 ...  2640.184 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A04E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A04E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A04E.fif
# [done]
# data:A04E.gdf, label:A04E.mat
# Extracting GDF parameters from /content/raw_data/A03E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 648774  =      0.000 ...  2595.096 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A03E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A03E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A03E.fif
# [done]
# data:A03E.gdf, label:A03E.mat
# Extracting GDF parameters from /content/raw_data/A07E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 673134  =      0.000 ...  2692.536 secs...
# /usr/lib/python3.12/contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Writing /content/cleaned_data/second_session/A07E.fif
# /tmp/ipykernel_4923/2108108794.py:29: RuntimeWarning: This filename (/content/cleaned_data/second_session/A07E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/A07E.fif
# [done]
# data:A07E.gdf, label:A07E.mat
# Writing /content/cleaned_data/second_session/Second_Session_Subjects.fif
# /tmp/ipykernel_4923/2108108794.py:55: RuntimeWarning: This filename (/content/cleaned_data/second_session/Second_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing /content/cleaned_data/second_session/Second_Session_Subjects.fif
# [done]
# [PosixPath('/content/cleaned_data/second_session/Second_Session_Subjects.fif')]

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '783': 7 Cue unknown

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('783')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('783'): 7}

# %%
epochs = mne.Epochs(final_raw, events[0], event_id=7, tmin=0, tmax=4, reject=None, baseline=None, preload=None)
second_session_data = epochs.get_data(copy=True)
# Out:
# Not setting metadata
# 2592 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2592 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
print("Second Session Dataset shape:",second_session_data.shape)
# Out:
# Second Session Dataset shape: (2592, 22, 1001)

# %% [markdown]
# ###Structuring Data

# %%
# Choosing Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Loss Function
criterion = nn.CrossEntropyLoss()

# Normalizing Labels to [0, 1, 2, 3]
y_train = first_session_labels - np.min(first_session_labels)
y_test = second_session_labels - np.min(second_session_labels)

# Normalizing Input features: z-score(mean=0, std=1)
X_first_session = (first_session_data - np.mean(first_session_data)) / np.std(first_session_data)
X_second_session = (second_session_data - np.mean(second_session_data)) / np.std(second_session_data)

X = np.concatenate((X_first_session, X_second_session))
y = np.concatenate((y_train, y_test))

# Spliting  Data: 90% for Train and 10% for Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# Converting to Tensor
X_train = torch.Tensor(X_train).unsqueeze(1).to(device)
X_test = torch.Tensor(X_test).unsqueeze(1).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test = torch.LongTensor(y_test).to(device)

# Creating Tensor Dataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# Printing the sizes
print("Size of X_train:", X_train.size())
print("Size of X_test:", X_test.size())
print("Size of y_train:", y_train.size())
print("Size of y_test:", y_test.size())
# Out:
# Size of X_train: torch.Size([4665, 1, 22, 1001])
# Size of X_test: torch.Size([519, 1, 22, 1001])
# Size of y_train: torch.Size([4665])
# Size of y_test: torch.Size([519])

# %% [markdown]
# #Training Class

# %%
class TrainModel():
    def __init__(self,):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def train_model(self, model, train_dataset, learning_rate=0.001, batch_size=64, epochs=500):
        model = model.to(self.device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        highest_train_accuracy = 0.0

        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            correct = 0
            total = 0
            for inputs, labels in train_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

            epoch_loss = running_loss / len(train_loader.dataset)
            epoch_accuracy = correct / total
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy
            print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {(epoch_accuracy*100):.2f}%")

        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)
        print("Highest Train Accuracy:", highest_train_accuracy)

        # Saving model
        torch.save(model.state_dict(), 'eegnet_model.pth')
        return model

# %% [markdown]
# #Evaluating Model

# %%
class EvalModel():
    def __init__(self, model):
        self.model = model.to(device)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    def test_model(self, test_dataset):
        self.model.eval()
        correct = 0
        total = 0
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = (correct / total) * 100
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")
        return accuracy

    def plot_confusion_matrix(self, test_dataset, classes):
        self.model.eval()
        y_pred = []
        y_true = []
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                outputs = self.model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                y_pred.append(predicted.item())
                y_true.append(labels.item())

        cf_matrix = confusion_matrix(y_true, y_pred)
        cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]

        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        plt.figure(figsize=(10, 7))
        sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='.2f')
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.savefig('confusion_matrix_model.png')
        plt.show()

# %% [markdown]
# #EEGNet Model

# %%
class EEGNetModel(nn.Module): # EEGNET-8,2
    def __init__(self, chans=22, classes=4, time_points=1001, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, dropout_rate=0.5, max_norm1=1, max_norm2=0.25):
        super(EEGNetModel, self).__init__()
        # Calculating FC input features
        linear_size = (time_points//(pk1*pk2))*f2

        # Temporal Filters
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )
        # Spatial Filters
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False), # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16),  groups=f2, bias=False, padding='same'), # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False), # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(linear_size, classes)

        # Apply max_norm constraint to the depthwise layer in block2
        self._apply_max_norm(self.block2[0], max_norm1)

        # Apply max_norm constraint to the linear layer
        self._apply_max_norm(self.fc, max_norm2)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ##Model Summery

# %%
input_size = (1, 22, 1001)
eegnet_model = EEGNetModel().to(device)
summary(eegnet_model, input_size)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:548: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv2d(
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 4]                   900
# ==========================================================================================
# Total params: 3,812
# Trainable params: 3,812
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.06
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 4]                   900
# ==========================================================================================
# Total params: 3,812
# Trainable params: 3,812
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.06
# ==========================================================================================

# %% [markdown]
# ##Training Model

# %%
eegnet_model = EEGNetModel().to(device)

# Training Hyperparameters
EPOCHS = 500
BATCH_SIZE = 64
LEARNING_RATE = 0.001
trainer = TrainModel()
trained_eegnet_model = trainer.train_model(eegnet_model, train_dataset, learning_rate=LEARNING_RATE,
                                   batch_size=BATCH_SIZE, epochs=EPOCHS)
torch.save(trained_eegnet_model.state_dict(), 'eegnet_model.pth')
# Out:
# Epoch 1/500, Loss: 1.3752, Accuracy: 28.25%
# Epoch 2/500, Loss: 1.3473, Accuracy: 32.26%
# Epoch 3/500, Loss: 1.3147, Accuracy: 36.59%
# Epoch 4/500, Loss: 1.2685, Accuracy: 39.96%
# Epoch 5/500, Loss: 1.2354, Accuracy: 43.30%
# Epoch 6/500, Loss: 1.2139, Accuracy: 44.95%
# Epoch 7/500, Loss: 1.1993, Accuracy: 45.66%
# Epoch 8/500, Loss: 1.1937, Accuracy: 45.79%
# Epoch 9/500, Loss: 1.1758, Accuracy: 46.45%
# Epoch 10/500, Loss: 1.1636, Accuracy: 48.45%
# Epoch 11/500, Loss: 1.1530, Accuracy: 47.80%
# Epoch 12/500, Loss: 1.1420, Accuracy: 48.19%
# Epoch 13/500, Loss: 1.1391, Accuracy: 48.66%
# Epoch 14/500, Loss: 1.1456, Accuracy: 48.75%
# Epoch 15/500, Loss: 1.1321, Accuracy: 49.15%
# Epoch 16/500, Loss: 1.1247, Accuracy: 50.23%
# Epoch 17/500, Loss: 1.1186, Accuracy: 50.20%
# Epoch 18/500, Loss: 1.1153, Accuracy: 50.29%
# Epoch 19/500, Loss: 1.1036, Accuracy: 52.00%
# Epoch 20/500, Loss: 1.1065, Accuracy: 50.59%
# Epoch 21/500, Loss: 1.1030, Accuracy: 51.58%
# Epoch 22/500, Loss: 1.0975, Accuracy: 52.22%
# Epoch 23/500, Loss: 1.0960, Accuracy: 50.57%
# Epoch 24/500, Loss: 1.0987, Accuracy: 51.77%
# Epoch 25/500, Loss: 1.0791, Accuracy: 51.94%
# Epoch 26/500, Loss: 1.0822, Accuracy: 51.96%
# Epoch 27/500, Loss: 1.0748, Accuracy: 52.97%
# Epoch 28/500, Loss: 1.0709, Accuracy: 52.75%
# Epoch 29/500, Loss: 1.0750, Accuracy: 52.52%
# Epoch 30/500, Loss: 1.0581, Accuracy: 52.97%
# Epoch 31/500, Loss: 1.0631, Accuracy: 53.33%
# Epoch 32/500, Loss: 1.0539, Accuracy: 53.76%
# Epoch 33/500, Loss: 1.0477, Accuracy: 53.74%
# Epoch 34/500, Loss: 1.0538, Accuracy: 53.70%
# Epoch 35/500, Loss: 1.0512, Accuracy: 54.00%
# Epoch 36/500, Loss: 1.0369, Accuracy: 54.86%
# Epoch 37/500, Loss: 1.0316, Accuracy: 55.01%
# Epoch 38/500, Loss: 1.0264, Accuracy: 55.37%
# Epoch 39/500, Loss: 1.0298, Accuracy: 54.43%
# Epoch 40/500, Loss: 1.0360, Accuracy: 55.39%
# Epoch 41/500, Loss: 1.0212, Accuracy: 56.46%
# Epoch 42/500, Loss: 1.0154, Accuracy: 57.00%
# Epoch 43/500, Loss: 1.0275, Accuracy: 55.91%
# Epoch 44/500, Loss: 1.0269, Accuracy: 55.20%
# Epoch 45/500, Loss: 1.0141, Accuracy: 55.86%
# Epoch 46/500, Loss: 1.0153, Accuracy: 56.33%
# Epoch 47/500, Loss: 1.0205, Accuracy: 55.80%
# Epoch 48/500, Loss: 0.9960, Accuracy: 57.26%
# Epoch 49/500, Loss: 1.0021, Accuracy: 56.66%
# Epoch 50/500, Loss: 1.0062, Accuracy: 56.74%
# Epoch 51/500, Loss: 1.0088, Accuracy: 56.01%
# Epoch 52/500, Loss: 0.9894, Accuracy: 57.32%
# Epoch 53/500, Loss: 0.9990, Accuracy: 56.76%
# Epoch 54/500, Loss: 1.0113, Accuracy: 57.30%
# Epoch 55/500, Loss: 0.9902, Accuracy: 58.07%
# Epoch 56/500, Loss: 0.9894, Accuracy: 57.08%
# Epoch 57/500, Loss: 0.9894, Accuracy: 57.73%
# Epoch 58/500, Loss: 0.9945, Accuracy: 58.14%
# Epoch 59/500, Loss: 0.9778, Accuracy: 57.64%
# Epoch 60/500, Loss: 0.9726, Accuracy: 59.42%
# Epoch 61/500, Loss: 0.9771, Accuracy: 58.61%
# Epoch 62/500, Loss: 0.9860, Accuracy: 57.53%
# Epoch 63/500, Loss: 0.9795, Accuracy: 57.68%
# Epoch 64/500, Loss: 0.9737, Accuracy: 58.54%
# Epoch 65/500, Loss: 0.9720, Accuracy: 58.61%
# Epoch 66/500, Loss: 0.9653, Accuracy: 59.06%
# Epoch 67/500, Loss: 0.9806, Accuracy: 59.14%
# Epoch 68/500, Loss: 0.9811, Accuracy: 58.37%
# Epoch 69/500, Loss: 0.9604, Accuracy: 58.95%
# Epoch 70/500, Loss: 0.9670, Accuracy: 59.36%
# Epoch 71/500, Loss: 0.9604, Accuracy: 60.02%
# Epoch 72/500, Loss: 0.9669, Accuracy: 59.29%
# Epoch 73/500, Loss: 0.9584, Accuracy: 59.34%
# Epoch 74/500, Loss: 0.9648, Accuracy: 59.42%
# Epoch 75/500, Loss: 0.9434, Accuracy: 61.16%
# Epoch 76/500, Loss: 0.9500, Accuracy: 59.55%
# Epoch 77/500, Loss: 0.9727, Accuracy: 59.38%
# Epoch 78/500, Loss: 0.9638, Accuracy: 59.06%
# Epoch 79/500, Loss: 0.9609, Accuracy: 58.41%
# Epoch 80/500, Loss: 0.9528, Accuracy: 59.59%
# Epoch 81/500, Loss: 0.9631, Accuracy: 59.40%
# Epoch 82/500, Loss: 0.9421, Accuracy: 60.75%
# Epoch 83/500, Loss: 0.9525, Accuracy: 60.66%
# Epoch 84/500, Loss: 0.9422, Accuracy: 60.69%
# Epoch 85/500, Loss: 0.9412, Accuracy: 60.26%
# Epoch 86/500, Loss: 0.9498, Accuracy: 60.11%
# Epoch 87/500, Loss: 0.9356, Accuracy: 60.56%
# Epoch 88/500, Loss: 0.9451, Accuracy: 60.60%
# Epoch 89/500, Loss: 0.9404, Accuracy: 60.41%
# Epoch 90/500, Loss: 0.9322, Accuracy: 62.02%
# Epoch 91/500, Loss: 0.9247, Accuracy: 61.80%
# Epoch 92/500, Loss: 0.9366, Accuracy: 60.75%
# Epoch 93/500, Loss: 0.9357, Accuracy: 60.64%
# Epoch 94/500, Loss: 0.9375, Accuracy: 60.47%
# Epoch 95/500, Loss: 0.9403, Accuracy: 60.79%
# Epoch 96/500, Loss: 0.9323, Accuracy: 60.92%
# Epoch 97/500, Loss: 0.9246, Accuracy: 61.52%
# Epoch 98/500, Loss: 0.9316, Accuracy: 60.21%
# Epoch 99/500, Loss: 0.9280, Accuracy: 60.32%
# Epoch 100/500, Loss: 0.9419, Accuracy: 60.43%
# Epoch 101/500, Loss: 0.9292, Accuracy: 61.46%
# Epoch 102/500, Loss: 0.9142, Accuracy: 61.54%
# Epoch 103/500, Loss: 0.9217, Accuracy: 61.56%
# Epoch 104/500, Loss: 0.9219, Accuracy: 62.32%
# Epoch 105/500, Loss: 0.9331, Accuracy: 60.71%
# Epoch 106/500, Loss: 0.9384, Accuracy: 60.81%
# Epoch 107/500, Loss: 0.9133, Accuracy: 61.37%
# Epoch 108/500, Loss: 0.9116, Accuracy: 62.10%
# Epoch 109/500, Loss: 0.9279, Accuracy: 61.26%
# Epoch 110/500, Loss: 0.9160, Accuracy: 61.18%
# Epoch 111/500, Loss: 0.9170, Accuracy: 61.84%
# Epoch 112/500, Loss: 0.9091, Accuracy: 62.57%
# Epoch 113/500, Loss: 0.9289, Accuracy: 61.29%
# Epoch 114/500, Loss: 0.9177, Accuracy: 61.07%
# Epoch 115/500, Loss: 0.8998, Accuracy: 62.55%
# Epoch 116/500, Loss: 0.9029, Accuracy: 62.10%
# Epoch 117/500, Loss: 0.9147, Accuracy: 61.71%
# Epoch 118/500, Loss: 0.8941, Accuracy: 62.29%
# Epoch 119/500, Loss: 0.9089, Accuracy: 62.55%
# Epoch 120/500, Loss: 0.9018, Accuracy: 62.81%
# Epoch 121/500, Loss: 0.9085, Accuracy: 61.80%
# Epoch 122/500, Loss: 0.9126, Accuracy: 61.82%
# Epoch 123/500, Loss: 0.9023, Accuracy: 62.81%
# Epoch 124/500, Loss: 0.9135, Accuracy: 62.08%
# Epoch 125/500, Loss: 0.9058, Accuracy: 62.94%
# Epoch 126/500, Loss: 0.8907, Accuracy: 63.37%
# Epoch 127/500, Loss: 0.8954, Accuracy: 62.40%
# Epoch 128/500, Loss: 0.9146, Accuracy: 62.89%
# Epoch 129/500, Loss: 0.9024, Accuracy: 62.47%
# Epoch 130/500, Loss: 0.8990, Accuracy: 62.40%
# Epoch 131/500, Loss: 0.9065, Accuracy: 62.27%
# Epoch 132/500, Loss: 0.9033, Accuracy: 62.68%
# Epoch 133/500, Loss: 0.8841, Accuracy: 63.77%
# Epoch 134/500, Loss: 0.8926, Accuracy: 63.39%
# Epoch 135/500, Loss: 0.8943, Accuracy: 62.81%
# Epoch 136/500, Loss: 0.9015, Accuracy: 62.57%
# Epoch 137/500, Loss: 0.8913, Accuracy: 63.71%
# Epoch 138/500, Loss: 0.9009, Accuracy: 62.77%
# Epoch 139/500, Loss: 0.8885, Accuracy: 62.92%
# Epoch 140/500, Loss: 0.8957, Accuracy: 63.17%
# Epoch 141/500, Loss: 0.8832, Accuracy: 63.75%
# Epoch 142/500, Loss: 0.8872, Accuracy: 63.32%
# Epoch 143/500, Loss: 0.8941, Accuracy: 63.34%
# Epoch 144/500, Loss: 0.9015, Accuracy: 62.64%
# Epoch 145/500, Loss: 0.8960, Accuracy: 63.32%
# Epoch 146/500, Loss: 0.8898, Accuracy: 63.69%
# Epoch 147/500, Loss: 0.8790, Accuracy: 63.49%
# Epoch 148/500, Loss: 0.8925, Accuracy: 62.92%
# Epoch 149/500, Loss: 0.8861, Accuracy: 63.90%
# Epoch 150/500, Loss: 0.8890, Accuracy: 63.54%
# Epoch 151/500, Loss: 0.8859, Accuracy: 63.56%
# Epoch 152/500, Loss: 0.8840, Accuracy: 63.47%
# Epoch 153/500, Loss: 0.8986, Accuracy: 62.34%
# Epoch 154/500, Loss: 0.8915, Accuracy: 63.19%
# Epoch 155/500, Loss: 0.8825, Accuracy: 63.41%
# Epoch 156/500, Loss: 0.8879, Accuracy: 62.79%
# Epoch 157/500, Loss: 0.8781, Accuracy: 63.64%
# Epoch 158/500, Loss: 0.8847, Accuracy: 63.71%
# Epoch 159/500, Loss: 0.8749, Accuracy: 64.67%
# Epoch 160/500, Loss: 0.8784, Accuracy: 63.67%
# Epoch 161/500, Loss: 0.8687, Accuracy: 63.90%
# Epoch 162/500, Loss: 0.8726, Accuracy: 63.52%
# Epoch 163/500, Loss: 0.8781, Accuracy: 63.26%
# Epoch 164/500, Loss: 0.8645, Accuracy: 64.33%
# Epoch 165/500, Loss: 0.8829, Accuracy: 63.88%
# Epoch 166/500, Loss: 0.8917, Accuracy: 63.37%
# Epoch 167/500, Loss: 0.8790, Accuracy: 63.84%
# Epoch 168/500, Loss: 0.8617, Accuracy: 65.17%
# Epoch 169/500, Loss: 0.8640, Accuracy: 64.29%
# Epoch 170/500, Loss: 0.8785, Accuracy: 63.13%
# Epoch 171/500, Loss: 0.8674, Accuracy: 64.29%
# Epoch 172/500, Loss: 0.8711, Accuracy: 63.99%
# Epoch 173/500, Loss: 0.8824, Accuracy: 63.58%
# Epoch 174/500, Loss: 0.8764, Accuracy: 64.01%
# Epoch 175/500, Loss: 0.8749, Accuracy: 63.92%
# Epoch 176/500, Loss: 0.8717, Accuracy: 63.84%
# Epoch 177/500, Loss: 0.8701, Accuracy: 64.24%
# Epoch 178/500, Loss: 0.8603, Accuracy: 64.22%
# Epoch 179/500, Loss: 0.8566, Accuracy: 65.94%
# Epoch 180/500, Loss: 0.8637, Accuracy: 64.09%
# Epoch 181/500, Loss: 0.8670, Accuracy: 64.27%
# Epoch 182/500, Loss: 0.8784, Accuracy: 63.79%
# Epoch 183/500, Loss: 0.8546, Accuracy: 64.42%
# Epoch 184/500, Loss: 0.8591, Accuracy: 65.21%
# Epoch 185/500, Loss: 0.8593, Accuracy: 64.01%
# Epoch 186/500, Loss: 0.8678, Accuracy: 64.37%
# Epoch 187/500, Loss: 0.8592, Accuracy: 64.22%
# Epoch 188/500, Loss: 0.8635, Accuracy: 64.09%
# Epoch 189/500, Loss: 0.8717, Accuracy: 63.32%
# Epoch 190/500, Loss: 0.8667, Accuracy: 65.02%
# Epoch 191/500, Loss: 0.8576, Accuracy: 64.31%
# Epoch 192/500, Loss: 0.8747, Accuracy: 64.82%
# Epoch 193/500, Loss: 0.8713, Accuracy: 64.05%
# Epoch 194/500, Loss: 0.8504, Accuracy: 65.64%
# Epoch 195/500, Loss: 0.8499, Accuracy: 65.23%
# Epoch 196/500, Loss: 0.8550, Accuracy: 64.12%
# Epoch 197/500, Loss: 0.8589, Accuracy: 65.51%
# Epoch 198/500, Loss: 0.8505, Accuracy: 65.62%
# Epoch 199/500, Loss: 0.8529, Accuracy: 64.91%
# Epoch 200/500, Loss: 0.8545, Accuracy: 65.19%
# Epoch 201/500, Loss: 0.8690, Accuracy: 63.79%
# Epoch 202/500, Loss: 0.8589, Accuracy: 64.33%
# Epoch 203/500, Loss: 0.8680, Accuracy: 64.61%
# Epoch 204/500, Loss: 0.8601, Accuracy: 65.12%
# Epoch 205/500, Loss: 0.8559, Accuracy: 65.68%
# Epoch 206/500, Loss: 0.8602, Accuracy: 65.08%
# Epoch 207/500, Loss: 0.8576, Accuracy: 65.08%
# Epoch 208/500, Loss: 0.8481, Accuracy: 65.14%
# Epoch 209/500, Loss: 0.8483, Accuracy: 64.99%
# Epoch 210/500, Loss: 0.8477, Accuracy: 66.07%
# Epoch 211/500, Loss: 0.8384, Accuracy: 66.43%
# Epoch 212/500, Loss: 0.8643, Accuracy: 65.06%
# Epoch 213/500, Loss: 0.8398, Accuracy: 65.87%
# Epoch 214/500, Loss: 0.8429, Accuracy: 64.82%
# Epoch 215/500, Loss: 0.8586, Accuracy: 64.05%
# Epoch 216/500, Loss: 0.8636, Accuracy: 65.08%
# Epoch 217/500, Loss: 0.8381, Accuracy: 65.68%
# Epoch 218/500, Loss: 0.8450, Accuracy: 65.36%
# Epoch 219/500, Loss: 0.8263, Accuracy: 66.41%
# Epoch 220/500, Loss: 0.8437, Accuracy: 65.66%
# Epoch 221/500, Loss: 0.8556, Accuracy: 64.95%
# Epoch 222/500, Loss: 0.8465, Accuracy: 65.66%
# Epoch 223/500, Loss: 0.8465, Accuracy: 65.55%
# Epoch 224/500, Loss: 0.8502, Accuracy: 65.14%
# Epoch 225/500, Loss: 0.8384, Accuracy: 66.35%
# Epoch 226/500, Loss: 0.8409, Accuracy: 65.94%
# Epoch 227/500, Loss: 0.8520, Accuracy: 65.04%
# Epoch 228/500, Loss: 0.8349, Accuracy: 65.89%
# Epoch 229/500, Loss: 0.8334, Accuracy: 65.44%
# Epoch 230/500, Loss: 0.8316, Accuracy: 65.68%
# Epoch 231/500, Loss: 0.8479, Accuracy: 65.62%
# Epoch 232/500, Loss: 0.8408, Accuracy: 65.94%
# Epoch 233/500, Loss: 0.8297, Accuracy: 65.96%
# Epoch 234/500, Loss: 0.8429, Accuracy: 65.81%
# Epoch 235/500, Loss: 0.8421, Accuracy: 64.87%
# Epoch 236/500, Loss: 0.8487, Accuracy: 65.34%
# Epoch 237/500, Loss: 0.8455, Accuracy: 66.09%
# Epoch 238/500, Loss: 0.8451, Accuracy: 65.74%
# Epoch 239/500, Loss: 0.8259, Accuracy: 66.58%
# Epoch 240/500, Loss: 0.8382, Accuracy: 65.70%
# Epoch 241/500, Loss: 0.8429, Accuracy: 65.72%
# Epoch 242/500, Loss: 0.8510, Accuracy: 65.36%
# Epoch 243/500, Loss: 0.8430, Accuracy: 65.85%
# Epoch 244/500, Loss: 0.8448, Accuracy: 65.85%
# Epoch 245/500, Loss: 0.8330, Accuracy: 65.29%
# Epoch 246/500, Loss: 0.8313, Accuracy: 65.85%
# Epoch 247/500, Loss: 0.8437, Accuracy: 65.55%
# Epoch 248/500, Loss: 0.8301, Accuracy: 66.52%
# Epoch 249/500, Loss: 0.8320, Accuracy: 66.15%
# Epoch 250/500, Loss: 0.8505, Accuracy: 64.87%
# Epoch 251/500, Loss: 0.8378, Accuracy: 66.09%
# Epoch 252/500, Loss: 0.8406, Accuracy: 66.24%
# Epoch 253/500, Loss: 0.8257, Accuracy: 65.66%
# Epoch 254/500, Loss: 0.8435, Accuracy: 66.24%
# Epoch 255/500, Loss: 0.8340, Accuracy: 65.19%
# Epoch 256/500, Loss: 0.8303, Accuracy: 66.52%
# Epoch 257/500, Loss: 0.8284, Accuracy: 66.09%
# Epoch 258/500, Loss: 0.8361, Accuracy: 66.13%
# Epoch 259/500, Loss: 0.8260, Accuracy: 66.62%
# Epoch 260/500, Loss: 0.8248, Accuracy: 65.94%
# Epoch 261/500, Loss: 0.8245, Accuracy: 66.69%
# Epoch 262/500, Loss: 0.8396, Accuracy: 65.25%
# Epoch 263/500, Loss: 0.8283, Accuracy: 66.80%
# Epoch 264/500, Loss: 0.8318, Accuracy: 66.00%
# Epoch 265/500, Loss: 0.8385, Accuracy: 66.28%
# Epoch 266/500, Loss: 0.8340, Accuracy: 65.94%
# Epoch 267/500, Loss: 0.8280, Accuracy: 66.69%
# Epoch 268/500, Loss: 0.8266, Accuracy: 66.80%
# Epoch 269/500, Loss: 0.8325, Accuracy: 65.87%
# Epoch 270/500, Loss: 0.8352, Accuracy: 65.98%
# Epoch 271/500, Loss: 0.8328, Accuracy: 66.09%
# Epoch 272/500, Loss: 0.8095, Accuracy: 67.29%
# Epoch 273/500, Loss: 0.8188, Accuracy: 66.86%
# Epoch 274/500, Loss: 0.8385, Accuracy: 65.77%
# Epoch 275/500, Loss: 0.8360, Accuracy: 66.28%
# Epoch 276/500, Loss: 0.8221, Accuracy: 66.02%
# Epoch 277/500, Loss: 0.8247, Accuracy: 66.90%
# Epoch 278/500, Loss: 0.8308, Accuracy: 66.26%
# Epoch 279/500, Loss: 0.8391, Accuracy: 65.77%
# Epoch 280/500, Loss: 0.8404, Accuracy: 65.79%
# Epoch 281/500, Loss: 0.8285, Accuracy: 66.28%
# Epoch 282/500, Loss: 0.8168, Accuracy: 66.75%
# Epoch 283/500, Loss: 0.8356, Accuracy: 66.32%
# Epoch 284/500, Loss: 0.8388, Accuracy: 65.59%
# Epoch 285/500, Loss: 0.8174, Accuracy: 67.05%
# Epoch 286/500, Loss: 0.8226, Accuracy: 66.82%
# Epoch 287/500, Loss: 0.8302, Accuracy: 66.24%
# Epoch 288/500, Loss: 0.8345, Accuracy: 65.25%
# Epoch 289/500, Loss: 0.8340, Accuracy: 66.00%
# Epoch 290/500, Loss: 0.8169, Accuracy: 66.58%
# Epoch 291/500, Loss: 0.8329, Accuracy: 65.66%
# Epoch 292/500, Loss: 0.8181, Accuracy: 67.46%
# Epoch 293/500, Loss: 0.8182, Accuracy: 66.95%
# Epoch 294/500, Loss: 0.8242, Accuracy: 66.54%
# Epoch 295/500, Loss: 0.8359, Accuracy: 66.07%
# Epoch 296/500, Loss: 0.8298, Accuracy: 65.98%
# Epoch 297/500, Loss: 0.8094, Accuracy: 66.52%
# Epoch 298/500, Loss: 0.8088, Accuracy: 67.33%
# Epoch 299/500, Loss: 0.8215, Accuracy: 66.62%
# Epoch 300/500, Loss: 0.8228, Accuracy: 66.60%
# Epoch 301/500, Loss: 0.8271, Accuracy: 65.38%
# Epoch 302/500, Loss: 0.8024, Accuracy: 67.97%
# Epoch 303/500, Loss: 0.8299, Accuracy: 66.99%
# Epoch 304/500, Loss: 0.8166, Accuracy: 67.10%
# Epoch 305/500, Loss: 0.8196, Accuracy: 66.28%
# Epoch 306/500, Loss: 0.8229, Accuracy: 66.39%
# Epoch 307/500, Loss: 0.8298, Accuracy: 66.88%
# Epoch 308/500, Loss: 0.8216, Accuracy: 66.62%
# Epoch 309/500, Loss: 0.8257, Accuracy: 67.20%
# Epoch 310/500, Loss: 0.8201, Accuracy: 66.86%
# Epoch 311/500, Loss: 0.8252, Accuracy: 66.58%
# Epoch 312/500, Loss: 0.8172, Accuracy: 67.29%
# Epoch 313/500, Loss: 0.8177, Accuracy: 67.46%
# Epoch 314/500, Loss: 0.8093, Accuracy: 67.59%
# Epoch 315/500, Loss: 0.8215, Accuracy: 66.65%
# Epoch 316/500, Loss: 0.8150, Accuracy: 67.12%
# Epoch 317/500, Loss: 0.8164, Accuracy: 67.61%
# Epoch 318/500, Loss: 0.8202, Accuracy: 66.15%
# Epoch 319/500, Loss: 0.8216, Accuracy: 67.18%
# Epoch 320/500, Loss: 0.8239, Accuracy: 66.39%
# Epoch 321/500, Loss: 0.8191, Accuracy: 66.37%
# Epoch 322/500, Loss: 0.8261, Accuracy: 66.32%
# Epoch 323/500, Loss: 0.8127, Accuracy: 66.95%
# Epoch 324/500, Loss: 0.8303, Accuracy: 66.52%
# Epoch 325/500, Loss: 0.8220, Accuracy: 66.82%
# Epoch 326/500, Loss: 0.8119, Accuracy: 67.61%
# Epoch 327/500, Loss: 0.8235, Accuracy: 66.30%
# Epoch 328/500, Loss: 0.8123, Accuracy: 66.82%
# Epoch 329/500, Loss: 0.8093, Accuracy: 67.10%
# Epoch 330/500, Loss: 0.8145, Accuracy: 67.10%
# Epoch 331/500, Loss: 0.8110, Accuracy: 66.65%
# Epoch 332/500, Loss: 0.8023, Accuracy: 67.72%
# Epoch 333/500, Loss: 0.8042, Accuracy: 67.42%
# Epoch 334/500, Loss: 0.8107, Accuracy: 67.07%
# Epoch 335/500, Loss: 0.8004, Accuracy: 67.44%
# Epoch 336/500, Loss: 0.8195, Accuracy: 66.73%
# Epoch 337/500, Loss: 0.8144, Accuracy: 66.69%
# Epoch 338/500, Loss: 0.8281, Accuracy: 66.17%
# Epoch 339/500, Loss: 0.8123, Accuracy: 67.01%
# Epoch 340/500, Loss: 0.8152, Accuracy: 67.63%
# Epoch 341/500, Loss: 0.8233, Accuracy: 65.98%
# Epoch 342/500, Loss: 0.8118, Accuracy: 67.22%
# Epoch 343/500, Loss: 0.8035, Accuracy: 67.18%
# Epoch 344/500, Loss: 0.8156, Accuracy: 67.03%
# Epoch 345/500, Loss: 0.8108, Accuracy: 67.52%
# Epoch 346/500, Loss: 0.8009, Accuracy: 67.16%
# Epoch 347/500, Loss: 0.7966, Accuracy: 67.46%
# Epoch 348/500, Loss: 0.8004, Accuracy: 66.67%
# Epoch 349/500, Loss: 0.8217, Accuracy: 66.02%
# Epoch 350/500, Loss: 0.8049, Accuracy: 67.10%
# Epoch 351/500, Loss: 0.8056, Accuracy: 67.65%
# Epoch 352/500, Loss: 0.8230, Accuracy: 66.71%
# Epoch 353/500, Loss: 0.8109, Accuracy: 67.46%
# Epoch 354/500, Loss: 0.7997, Accuracy: 67.05%
# Epoch 355/500, Loss: 0.8129, Accuracy: 66.43%
# Epoch 356/500, Loss: 0.8124, Accuracy: 66.39%
# Epoch 357/500, Loss: 0.7991, Accuracy: 68.04%
# Epoch 358/500, Loss: 0.8114, Accuracy: 67.72%
# Epoch 359/500, Loss: 0.8097, Accuracy: 67.67%
# Epoch 360/500, Loss: 0.8084, Accuracy: 67.07%
# Epoch 361/500, Loss: 0.8161, Accuracy: 66.97%
# Epoch 362/500, Loss: 0.8210, Accuracy: 66.32%
# Epoch 363/500, Loss: 0.8270, Accuracy: 65.92%
# Epoch 364/500, Loss: 0.8005, Accuracy: 67.76%
# Epoch 365/500, Loss: 0.8065, Accuracy: 66.84%
# Epoch 366/500, Loss: 0.8195, Accuracy: 66.67%
# Epoch 367/500, Loss: 0.8161, Accuracy: 66.07%
# Epoch 368/500, Loss: 0.7943, Accuracy: 68.23%
# Epoch 369/500, Loss: 0.8064, Accuracy: 67.33%
# Epoch 370/500, Loss: 0.8168, Accuracy: 67.61%
# Epoch 371/500, Loss: 0.7955, Accuracy: 68.00%
# Epoch 372/500, Loss: 0.8060, Accuracy: 67.67%
# Epoch 373/500, Loss: 0.8169, Accuracy: 67.35%
# Epoch 374/500, Loss: 0.8015, Accuracy: 67.22%
# Epoch 375/500, Loss: 0.7847, Accuracy: 68.55%
# Epoch 376/500, Loss: 0.7973, Accuracy: 67.61%
# Epoch 377/500, Loss: 0.8150, Accuracy: 66.37%
# Epoch 378/500, Loss: 0.8150, Accuracy: 66.88%
# Epoch 379/500, Loss: 0.7989, Accuracy: 67.61%
# Epoch 380/500, Loss: 0.8063, Accuracy: 67.65%
# Epoch 381/500, Loss: 0.8020, Accuracy: 66.88%
# Epoch 382/500, Loss: 0.8110, Accuracy: 67.80%
# Epoch 383/500, Loss: 0.8001, Accuracy: 67.57%
# Epoch 384/500, Loss: 0.8099, Accuracy: 67.76%
# Epoch 385/500, Loss: 0.8165, Accuracy: 67.44%
# Epoch 386/500, Loss: 0.8064, Accuracy: 67.48%
# Epoch 387/500, Loss: 0.7962, Accuracy: 67.95%
# Epoch 388/500, Loss: 0.7966, Accuracy: 68.25%
# Epoch 389/500, Loss: 0.7977, Accuracy: 68.38%
# Epoch 390/500, Loss: 0.7936, Accuracy: 68.27%
# Epoch 391/500, Loss: 0.7826, Accuracy: 68.00%
# Epoch 392/500, Loss: 0.8076, Accuracy: 67.48%
# Epoch 393/500, Loss: 0.7949, Accuracy: 68.08%
# Epoch 394/500, Loss: 0.7847, Accuracy: 68.17%
# Epoch 395/500, Loss: 0.8039, Accuracy: 67.72%
# Epoch 396/500, Loss: 0.8202, Accuracy: 67.65%
# Epoch 397/500, Loss: 0.7951, Accuracy: 67.67%
# Epoch 398/500, Loss: 0.7969, Accuracy: 67.65%
# Epoch 399/500, Loss: 0.7935, Accuracy: 67.16%
# Epoch 400/500, Loss: 0.8033, Accuracy: 67.72%
# Epoch 401/500, Loss: 0.7946, Accuracy: 67.78%
# Epoch 402/500, Loss: 0.8135, Accuracy: 66.86%
# Epoch 403/500, Loss: 0.7930, Accuracy: 67.80%
# Epoch 404/500, Loss: 0.7930, Accuracy: 68.51%
# Epoch 405/500, Loss: 0.8015, Accuracy: 67.89%
# Epoch 406/500, Loss: 0.7988, Accuracy: 67.59%
# Epoch 407/500, Loss: 0.7973, Accuracy: 67.40%
# Epoch 408/500, Loss: 0.8004, Accuracy: 67.78%
# Epoch 409/500, Loss: 0.7950, Accuracy: 68.75%
# Epoch 410/500, Loss: 0.8009, Accuracy: 67.22%
# Epoch 411/500, Loss: 0.7885, Accuracy: 68.60%
# Epoch 412/500, Loss: 0.8022, Accuracy: 67.10%
# Epoch 413/500, Loss: 0.8167, Accuracy: 67.55%
# Epoch 414/500, Loss: 0.7917, Accuracy: 67.76%
# Epoch 415/500, Loss: 0.8134, Accuracy: 67.59%
# Epoch 416/500, Loss: 0.7853, Accuracy: 68.34%
# Epoch 417/500, Loss: 0.8019, Accuracy: 67.22%
# Epoch 418/500, Loss: 0.8001, Accuracy: 67.70%
# Epoch 419/500, Loss: 0.7945, Accuracy: 68.21%
# Epoch 420/500, Loss: 0.7882, Accuracy: 67.55%
# Epoch 421/500, Loss: 0.7964, Accuracy: 68.00%
# Epoch 422/500, Loss: 0.8056, Accuracy: 67.65%
# Epoch 423/500, Loss: 0.7968, Accuracy: 67.74%
# Epoch 424/500, Loss: 0.7903, Accuracy: 68.30%
# Epoch 425/500, Loss: 0.7988, Accuracy: 67.48%
# Epoch 426/500, Loss: 0.7901, Accuracy: 67.40%
# Epoch 427/500, Loss: 0.7729, Accuracy: 69.13%
# Epoch 428/500, Loss: 0.8023, Accuracy: 67.20%
# Epoch 429/500, Loss: 0.8109, Accuracy: 66.65%
# Epoch 430/500, Loss: 0.8019, Accuracy: 68.19%
# Epoch 431/500, Loss: 0.7986, Accuracy: 66.69%
# Epoch 432/500, Loss: 0.7925, Accuracy: 67.93%
# Epoch 433/500, Loss: 0.7848, Accuracy: 68.23%
# Epoch 434/500, Loss: 0.7933, Accuracy: 68.27%
# Epoch 435/500, Loss: 0.8214, Accuracy: 65.83%
# Epoch 436/500, Loss: 0.7995, Accuracy: 67.50%
# Epoch 437/500, Loss: 0.7825, Accuracy: 68.27%
# Epoch 438/500, Loss: 0.7877, Accuracy: 68.21%
# Epoch 439/500, Loss: 0.7925, Accuracy: 67.89%
# Epoch 440/500, Loss: 0.8087, Accuracy: 67.89%
# Epoch 441/500, Loss: 0.8058, Accuracy: 68.08%
# Epoch 442/500, Loss: 0.7994, Accuracy: 67.74%
# Epoch 443/500, Loss: 0.7921, Accuracy: 67.89%
# Epoch 444/500, Loss: 0.7997, Accuracy: 67.01%
# Epoch 445/500, Loss: 0.7818, Accuracy: 68.32%
# Epoch 446/500, Loss: 0.8069, Accuracy: 67.59%
# Epoch 447/500, Loss: 0.7889, Accuracy: 68.23%
# Epoch 448/500, Loss: 0.7672, Accuracy: 69.09%
# Epoch 449/500, Loss: 0.7973, Accuracy: 68.40%
# Epoch 450/500, Loss: 0.7981, Accuracy: 67.50%
# Epoch 451/500, Loss: 0.7884, Accuracy: 67.65%
# Epoch 452/500, Loss: 0.7830, Accuracy: 68.81%
# Epoch 453/500, Loss: 0.7922, Accuracy: 68.79%
# Epoch 454/500, Loss: 0.7892, Accuracy: 67.72%
# Epoch 455/500, Loss: 0.7946, Accuracy: 68.34%
# Epoch 456/500, Loss: 0.7910, Accuracy: 68.19%
# Epoch 457/500, Loss: 0.7905, Accuracy: 67.63%
# Epoch 458/500, Loss: 0.7828, Accuracy: 68.96%
# Epoch 459/500, Loss: 0.7738, Accuracy: 68.47%
# Epoch 460/500, Loss: 0.7871, Accuracy: 68.42%
# Epoch 461/500, Loss: 0.7881, Accuracy: 68.08%
# Epoch 462/500, Loss: 0.7787, Accuracy: 68.32%
# Epoch 463/500, Loss: 0.7894, Accuracy: 67.59%
# Epoch 464/500, Loss: 0.7840, Accuracy: 69.11%
# Epoch 465/500, Loss: 0.8035, Accuracy: 68.00%
# Epoch 466/500, Loss: 0.7848, Accuracy: 68.47%
# Epoch 467/500, Loss: 0.7857, Accuracy: 68.25%
# Epoch 468/500, Loss: 0.8061, Accuracy: 66.99%
# Epoch 469/500, Loss: 0.7820, Accuracy: 68.02%
# Epoch 470/500, Loss: 0.7928, Accuracy: 67.85%
# Epoch 471/500, Loss: 0.7937, Accuracy: 68.25%
# Epoch 472/500, Loss: 0.7796, Accuracy: 69.82%
# Epoch 473/500, Loss: 0.7897, Accuracy: 68.36%
# Epoch 474/500, Loss: 0.7837, Accuracy: 68.15%
# Epoch 475/500, Loss: 0.7732, Accuracy: 69.07%
# Epoch 476/500, Loss: 0.7824, Accuracy: 68.12%
# Epoch 477/500, Loss: 0.7661, Accuracy: 69.32%
# Epoch 478/500, Loss: 0.7782, Accuracy: 68.42%
# Epoch 479/500, Loss: 0.7817, Accuracy: 68.70%
# Epoch 480/500, Loss: 0.8056, Accuracy: 68.21%
# Epoch 481/500, Loss: 0.7886, Accuracy: 68.87%
# Epoch 482/500, Loss: 0.7881, Accuracy: 68.40%
# Epoch 483/500, Loss: 0.7812, Accuracy: 68.23%
# Epoch 484/500, Loss: 0.7891, Accuracy: 68.85%
# Epoch 485/500, Loss: 0.7898, Accuracy: 68.79%
# Epoch 486/500, Loss: 0.7949, Accuracy: 67.61%
# Epoch 487/500, Loss: 0.7871, Accuracy: 68.30%
# Epoch 488/500, Loss: 0.7822, Accuracy: 68.68%
# Epoch 489/500, Loss: 0.7866, Accuracy: 68.00%
# Epoch 490/500, Loss: 0.7873, Accuracy: 69.00%
# Epoch 491/500, Loss: 0.7885, Accuracy: 68.40%
# Epoch 492/500, Loss: 0.7840, Accuracy: 67.76%
# Epoch 493/500, Loss: 0.7766, Accuracy: 68.27%
# Epoch 494/500, Loss: 0.7884, Accuracy: 68.66%
# Epoch 495/500, Loss: 0.7856, Accuracy: 67.85%
# Epoch 496/500, Loss: 0.7888, Accuracy: 68.53%
# Epoch 497/500, Loss: 0.7847, Accuracy: 67.78%
# Epoch 498/500, Loss: 0.7774, Accuracy: 68.55%
# Epoch 499/500, Loss: 0.7913, Accuracy: 67.76%
# Epoch 500/500, Loss: 0.7914, Accuracy: 67.89%
# Average Loss: 0.7913730436582658
# Highest Train Accuracy: 0.6981779206859593

# %% [markdown]
# ##Evaluating Model

# %%
classes_list = ['Left', 'Right', 'Foot', 'Tongue']
eval_model = EvalModel(trained_eegnet_model)
test_accuracy = eval_model.test_model(test_dataset)
eval_model.plot_confusion_matrix(test_dataset, classes_list)
# Out:
# /------------------------------/
# Test Accuracy: 69.75%
# /------------------------------/
